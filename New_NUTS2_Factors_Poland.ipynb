# %% [markdown]
# ### Adding more factors on NUTS2 level
#
# - The notebook begins with importing data from multiple sources, including Excel and CSV files. It involves loading datasets and merging new factors on NUTS 2 for Poland. The focus on different socio-economic indicators will help in conducting a comprehensive analysis of regions in Poland. We will use the final dataset to the modeling part.
# - The notebook reflects a focus on adding new factors to the existing modeling framework for Poland, particularly at the NUTS 3 level. Key considerations include the temporal availability of these factors, with a notable limitation that the new factors are available only for 2014-2020, unlike the existing dataset covering 2007-2020.

# %%
import pandas as pd
import numpy as np

# %%
# Load datasets
df = pd.read_excel("full_data_pl.xlsx")
wynagrodzenie = pd.read_csv('SZKO_4058_CTAB_20231123195156.csv', delimiter = ';')
mapping_data = pd.read_excel("clean_mapping_pl.xlsx")
wynagrodzenie = wynagrodzenie[['Kod', 'Nazwa']]
wynagrodzenie
# Out:
#             Kod                    Nazwa
# 0   11212000000      PODREGION KRAKOWSKI
# 1   11212100000  PODREGION MIASTO KRAKÓW
# 2   11212200000    PODREGION NOWOSĄDECKI
# 3   11212300000    PODREGION OŚWIĘCIMSKI
# 4   11212400000      PODREGION TARNOWSKI
# ..          ...                      ...
# 68  71422600000     PODREGION OSTROŁĘCKI
# 69  71422700000       PODREGION RADOMSKI
# 70  71427000000         PODREGION PŁOCKI
# 71  71427100000      PODREGION SIEDLECKI
# 72  71427300000    PODREGION ŻYRARDOWSKI
#
# [73 rows x 2 columns]

# %%
# There are some misspellings that might cause and issue in merging the datasets. We will correct them
replacement_dict = {
    'PODREGION OLSZYŃSKI': 'PODREGION OLSZTYŃSKI',
    'PODREGION SANDOMIERSKO - JĘDRZEJOWSKI': 'PODREGION SANDOMIERSKO-JĘDRZEJOWSKI',
    'PODREGION WARSZAWA WSCHODNIA':'PODREGION WARSZAWSKI WSCHODNI',
    'PODREGION ŁOMŻYNSKI':'PODREGION ŁOMŻYŃSKI',
    'PODREGION KOSZALINSKI':'PODREGION KOSZALIŃSKI',
    'PODREGION KROSNIEŃSKI':'PODREGION KROŚNIEŃSKI',
    'PODREGION GLIWCKI':'PODREGION GLIWICKI',
    'PODREGION GRUDZIADZKI':'PODREGION GRUDZIĄDZKI'

}

# Replace values in the 'NUTS3' column
mapping_data['NUTS3'] = mapping_data['NUTS3'].replace(replacement_dict)
mapping_data
# Out:
#     Unnamed: 0                                NUTS1 NUTS1 CODE  \
# 0            0                 MAKROREGION PÓŁNOCNY        PL6
# 1            1                 MAKROREGION WSCHODNI        PL8
# 2            2                 MAKROREGION PÓŁNOCNY        PL6
# 3            3               MAKROREGION POŁUDNIOWY        PL2
# 4            4                MAKROREGION CENTRALNY        PL7
# ..         ...                                  ...        ...
# 67          67        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 68          68                 MAKROREGION PÓŁNOCNY        PL6
# 69          69        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 70          70  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 71          71      MAKROREGION POŁUDNIOWO-ZACHODNI        PL5
#
#                           NUTS2 NUTS2 CODE                      NUTS3  \
# 0     REGION KUJAWSKO-POMORSKIE       PL61       PODREGION WROCŁAWSKI
# 1              REGION PODLASKIE       PL84         PODREGION SUWALSKI
# 2    REGION WARMIŃSKO-MAZURSKIE       PL62       PODREGION OLSZTYŃSKI
# 3                REGION ŚLĄSKIE       PL22      PODREGION SOSNOWIECKI
# 4                REGION ŁÓDZKIE       PL71      PODREGION PIOTRKOWSKI
# ..                          ...        ...                        ...
# 67         REGION WIELKOPOLSKIE       PL41    PODREGION MIASTO POZNAŃ
# 68    REGION KUJAWSKO-POMORSKIE       PL61          PODREGION ŚWIECKI
# 69    REGION ZACHODNIOPOMORSKIE       PL42  PODREGION MIASTO SZCZECIN
# 70  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION MIASTO WARSZAWA
# 71          REGION DOLNOŚLĄSKIE       PL51   PODREGION MIASTO WROCŁAW
#
#    NUTS3 CODE
# 0       PL619
# 1       PL843
# 2       PL622
# 3       PL22B
# 4       PL713
# ..        ...
# 67      PL415
# 68      PL618
# 69      PL424
# 70      PL911
# 71      PL514
#
# [72 rows x 7 columns]

# %%
# Make a copy of the DataFrame
wynagrodzenie_long = wynagrodzenie.copy()

# %%
# Check unique values
wynagrodzenie_long['Nazwa'].unique()
# Out:
# array(['PODREGION KRAKOWSKI', 'PODREGION MIASTO KRAKÓW',
#        'PODREGION NOWOSĄDECKI', 'PODREGION OŚWIĘCIMSKI',
#        'PODREGION TARNOWSKI', 'PODREGION NOWOTARSKI', 'PODREGION BIELSKI',
#        'PODREGION BYTOMSKI', 'PODREGION CZĘSTOCHOWSKI',
#        'PODREGION GLIWICKI', 'PODREGION KATOWICKI', 'PODREGION RYBNICKI',
#        'PODREGION SOSNOWIECKI', 'PODREGION TYSKI', 'PODREGION GORZOWSKI',
#        'PODREGION ZIELONOGÓRSKI', 'PODREGION KALISKI',
#        'PODREGION KONIŃSKI', 'PODREGION LESZCZYŃSKI', 'PODREGION PILSKI',
#        'PODREGION POZNAŃSKI', 'PODREGION MIASTO POZNAŃ',
#        'PODREGION KOSZALIŃSKI', 'PODREGION SZCZECINECKO-PYRZYCKI',
#        'PODREGION MIASTO SZCZECIN', 'PODREGION SZCZECIŃSKI',
#        'PODREGION JELENIOGÓRSKI', 'PODREGION LEGNICKO-GŁOGOWSKI',
#        'PODREGION WAŁBRZYSKI', 'PODREGION WROCŁAWSKI',
#        'PODREGION MIASTO WROCŁAW', 'PODREGION NYSKI', 'PODREGION OPOLSKI',
#        'PODREGION BYDGOSKO-TORUŃSKI', 'PODREGION GRUDZIĄDZKI',
#        'PODREGION WŁOCŁAWSKI', 'PODREGION INOWROCŁAWSKI',
#        'PODREGION ŚWIECKI', 'PODREGION GDAŃSKI', 'PODREGION SŁUPSKI',
#        'PODREGION STAROGARDZKI', 'PODREGION TRÓJMIEJSKI',
#        'PODREGION CHOJNICKI', 'PODREGION ELBLĄSKI', 'PODREGION EŁCKI',
#        'PODREGION OLSZTYŃSKI', 'PODREGION ŁÓDZKI',
#        'PODREGION MIASTO ŁÓDŹ', 'PODREGION PIOTRKOWSKI',
#        'PODREGION SIERADZKI', 'PODREGION SKIERNIEWICKI',
#        'PODREGION KIELECKI', 'PODREGION SANDOMIERSKO-JĘDRZEJOWSKI',
#        'PODREGION BIALSKI', 'PODREGION CHEŁMSKO-ZAMOJSKI',
#        'PODREGION LUBELSKI', 'PODREGION PUŁAWSKI',
#        'PODREGION KROŚNIEŃSKI', 'PODREGION PRZEMYSKI',
#        'PODREGION RZESZOWSKI', 'PODREGION TARNOBRZESKI',
#        'PODREGION BIAŁOSTOCKI', 'PODREGION ŁOMŻYŃSKI',
#        'PODREGION SUWALSKI', 'PODREGION MIASTO WARSZAWA',
#        'PODREGION WARSZAWSKI WSCHODNI', 'PODREGION WARSZAWSKI ZACHODNI',
#        'PODREGION CIECHANOWSKI', 'PODREGION OSTROŁĘCKI',
#        'PODREGION RADOMSKI', 'PODREGION PŁOCKI', 'PODREGION SIEDLECKI',
#        'PODREGION ŻYRARDOWSKI'], dtype=object)

# %%
# Check unique values
unique_in_mapping = set(wynagrodzenie_long['Nazwa']) - set(mapping_data['NUTS3'])
unique_in_mapping
# Out:
# {'PODREGION WARSZAWSKI ZACHODNI', 'PODREGION WŁOCŁAWSKI'}

# %%
# Check unique values
unique_in_mapping = set(mapping_data['NUTS3']) - set(wynagrodzenie_long['Nazwa'])
unique_in_mapping
# Out:
# set()

# %%
# Check unique values
mapping_data['NUTS3']
# Out:
# 0          PODREGION WROCŁAWSKI
# 1            PODREGION SUWALSKI
# 2          PODREGION OLSZTYŃSKI
# 3         PODREGION SOSNOWIECKI
# 4         PODREGION PIOTRKOWSKI
#                 ...
# 67      PODREGION MIASTO POZNAŃ
# 68            PODREGION ŚWIECKI
# 69    PODREGION MIASTO SZCZECIN
# 70    PODREGION MIASTO WARSZAWA
# 71     PODREGION MIASTO WROCŁAW
# Name: NUTS3, Length: 72, dtype: object

# %%
wynagrodzenie_long['Nazwa']
# Out:
# 0         PODREGION KRAKOWSKI
# 1     PODREGION MIASTO KRAKÓW
# 2       PODREGION NOWOSĄDECKI
# 3       PODREGION OŚWIĘCIMSKI
# 4         PODREGION TARNOWSKI
#                ...
# 68       PODREGION OSTROŁĘCKI
# 69         PODREGION RADOMSKI
# 70           PODREGION PŁOCKI
# 71        PODREGION SIEDLECKI
# 72      PODREGION ŻYRARDOWSKI
# Name: Nazwa, Length: 73, dtype: object

# %%
common_elements = set(mapping_data['NUTS3']).intersection(set(wynagrodzenie_long['Nazwa']))
len(common_elements)
# Out:
# 71

# %%
# Merge with mapping_data
merged_df = pd.merge(mapping_data, wynagrodzenie_long, left_on=['NUTS3'], right_on=['Nazwa'], how='left')

merged_df=merged_df.drop(["Nazwa"], axis = 1)

merged_df
# Out:
#     Unnamed: 0                                NUTS1 NUTS1 CODE  \
# 0            0                 MAKROREGION PÓŁNOCNY        PL6
# 1            1                 MAKROREGION WSCHODNI        PL8
# 2            2                 MAKROREGION PÓŁNOCNY        PL6
# 3            3               MAKROREGION POŁUDNIOWY        PL2
# 4            4                MAKROREGION CENTRALNY        PL7
# ..         ...                                  ...        ...
# 67          67        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 68          68                 MAKROREGION PÓŁNOCNY        PL6
# 69          69        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 70          70  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 71          71      MAKROREGION POŁUDNIOWO-ZACHODNI        PL5
#
#                           NUTS2 NUTS2 CODE                      NUTS3  \
# 0     REGION KUJAWSKO-POMORSKIE       PL61       PODREGION WROCŁAWSKI
# 1              REGION PODLASKIE       PL84         PODREGION SUWALSKI
# 2    REGION WARMIŃSKO-MAZURSKIE       PL62       PODREGION OLSZTYŃSKI
# 3                REGION ŚLĄSKIE       PL22      PODREGION SOSNOWIECKI
# 4                REGION ŁÓDZKIE       PL71      PODREGION PIOTRKOWSKI
# ..                          ...        ...                        ...
# 67         REGION WIELKOPOLSKIE       PL41    PODREGION MIASTO POZNAŃ
# 68    REGION KUJAWSKO-POMORSKIE       PL61          PODREGION ŚWIECKI
# 69    REGION ZACHODNIOPOMORSKIE       PL42  PODREGION MIASTO SZCZECIN
# 70  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION MIASTO WARSZAWA
# 71          REGION DOLNOŚLĄSKIE       PL51   PODREGION MIASTO WROCŁAW
#
#    NUTS3 CODE          Kod
# 0       PL619  30210400000
# 1       PL843  62013900000
# 2       PL622  42815600000
# 3       PL22B  12415000000
# 4       PL713  51011700000
# ..        ...          ...
# 67      PL415  23016200000
# 68      PL618  40416800000
# 69      PL424  23216500000
# 70      PL911  71412800000
# 71      PL514  30210500000
#
# [72 rows x 8 columns]

# %%
# We are missing one code and region that was not in mapping, we will add it manually now
new_row = {'NUTS1': 'MAKROREGION WOJEWÓDZTWO MAZOWIECKIE', 'NUTS1 CODE': 'PL9', 'NUTS2':'REGION WARSZAWSKI STOŁECZNY','NUTS2 CODE' : 'PL91', 'NUTS3':'PODREGION WARSZAWSKI ZACHODNI', 'NUTS3 CODE':'PL913', 'Kod': '71413000000'}

# Append the new row to the DataFrame
merged_df = merged_df.append(new_row, ignore_index=True)

merged_df
# Out:
# /var/folders/vn/7p3t4_3n02gcv591cgws1gw80000gn/T/ipykernel_18152/2282704114.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_df = merged_df.append(new_row, ignore_index=True)
#     Unnamed: 0                                NUTS1 NUTS1 CODE  \
# 0          0.0                 MAKROREGION PÓŁNOCNY        PL6
# 1          1.0                 MAKROREGION WSCHODNI        PL8
# 2          2.0                 MAKROREGION PÓŁNOCNY        PL6
# 3          3.0               MAKROREGION POŁUDNIOWY        PL2
# 4          4.0                MAKROREGION CENTRALNY        PL7
# ..         ...                                  ...        ...
# 69        69.0        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 70        70.0  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 71        71.0      MAKROREGION POŁUDNIOWO-ZACHODNI        PL5
# 72         NaN  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 73         NaN  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
#
#                           NUTS2 NUTS2 CODE                          NUTS3  \
# 0     REGION KUJAWSKO-POMORSKIE       PL61           PODREGION WROCŁAWSKI
# 1              REGION PODLASKIE       PL84             PODREGION SUWALSKI
# 2    REGION WARMIŃSKO-MAZURSKIE       PL62           PODREGION OLSZTYŃSKI
# 3                REGION ŚLĄSKIE       PL22          PODREGION SOSNOWIECKI
# 4                REGION ŁÓDZKIE       PL71          PODREGION PIOTRKOWSKI
# ..                          ...        ...                            ...
# 69    REGION ZACHODNIOPOMORSKIE       PL42      PODREGION MIASTO SZCZECIN
# 70  REGION WARSZAWSKI STOŁECZNY       PL91      PODREGION MIASTO WARSZAWA
# 71          REGION DOLNOŚLĄSKIE       PL51       PODREGION MIASTO WROCŁAW
# 72  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION WARSZAWSKI ZACHODNI
# 73  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION WARSZAWSKI ZACHODNI
#
#    NUTS3 CODE          Kod
# 0       PL619  30210400000
# 1       PL843  62013900000
# 2       PL622  42815600000
# 3       PL22B  12415000000
# 4       PL713  51011700000
# ..        ...          ...
# 69      PL424  23216500000
# 70      PL911  71412800000
# 71      PL514  30210500000
# 72      PL913  71413000000
# 73      PL913  71413000000
#
# [74 rows x 8 columns]

# %% [markdown]
# ### We will add Kod column to our full Poland data (df) to have this system there too

# %%
df
# Out:
#       Unnamed: 0 NUTS3 CODE  TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213         2007     756.30      428.6    13200
# 1              1      PL213         2008     756.40      428.6    15100
# 2              2      PL213         2009     761.42      428.6    12800
# 3              3      PL213         2010     757.11      428.6    14600
# 4              4      PL213         2011     758.21      433.6    15300
# ...          ...        ...          ...        ...        ...      ...
# 1017        1017      PL926         2016     259.80      108.3     9800
# 1018        1018      PL926         2017     259.70      107.8    10500
# 1019        1019      PL926         2018     259.80      107.4    11000
# 1020        1020      PL926         2019     259.10      107.1    11700
# 1021        1021      PL926         2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1017                 35   2556.74  11155.56            4471.49
# 1018                 36   2739.42  11661.73            4595.52
# 1019                 36   2857.49  12177.18            4722.54
# 1020                 37   3040.11  13065.19            5001.82
# 1021                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1017              17200                 61        2272.64           9916
# 1018              17700                 60        2425.65          10326
# 1019              18200                 60        2502.64          10665
# 1020              19300                 62        2671.96          11483
# 1021              19900                 66        2725.19          12108
#
# [1022 rows x 14 columns]

# %%
common_elements = set(df['NUTS3 CODE']).intersection(set(merged_df['NUTS3 CODE']))
len(common_elements)
# Out:
# 73

# %%
# Create a new DataFrame with only 'NUTS3 CODE' and 'Kod' columns from merged_df
merged_df_subset = merged_df[['NUTS3 CODE', 'Kod']]

# Merge df with merged_df_subset on 'NUTS3 CODE'
final = df.merge(merged_df_subset, on='NUTS3 CODE', how='left')

final
# Out:
#       Unnamed: 0 NUTS3 CODE  TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213         2007     756.30      428.6    13200
# 1              1      PL213         2008     756.40      428.6    15100
# 2              2      PL213         2009     761.42      428.6    12800
# 3              3      PL213         2010     757.11      428.6    14600
# 4              4      PL213         2011     758.21      433.6    15300
# ...          ...        ...          ...        ...        ...      ...
# 1031        1017      PL926         2016     259.80      108.3     9800
# 1032        1018      PL926         2017     259.70      107.8    10500
# 1033        1019      PL926         2018     259.80      107.4    11000
# 1034        1020      PL926         2019     259.10      107.1    11700
# 1035        1021      PL926         2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod
# 0     11212100000
# 1     11212100000
# 2     11212100000
# 3     11212100000
# 4     11212100000
# ...           ...
# 1031  71427300000
# 1032  71427300000
# 1033  71427300000
# 1034  71427300000
# 1035  71427300000
#
# [1036 rows x 15 columns]

# %%
# Check missing values
missing = final[final['Kod'].isnull()]
missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, NUTS3 CODE, TIME_PERIOD, POP (THS), EMP (THS), EUR_HAB, EUR_HAB_EU27_2020, MIO_EUR, MIO_NAC, MIO_PPS_EU27_2020, PPS_EU27_2020_HAB, PPS_HAB_EU27_2020, GVA (MIO_EUR), GVA (MIO_NAC), Kod]
# Index: []

# %% [markdown]
# #### Adding new factor - przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej 2007 - 2020

# %%
wyna = pd.read_csv('WYNA_2497_CTAB_20231126095948.csv', delimiter=';')
wyna
# Out:
#          Kod                  Nazwa  \
# 0     201000   Powiat bolesławiecki
# 1     202000  Powiat dzierżoniowski
# 2     203000       Powiat głogowski
# 3     204000        Powiat górowski
# 4     205000        Powiat jaworski
# ..       ...                    ...
# 375  3217000         Powiat wałecki
# 376  3218000         Powiat łobeski
# 377  3261000     Powiat m. Koszalin
# 378  3262000     Powiat m. Szczecin
# 379  3263000  Powiat m. Świnoujście
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2007;[%]  \
# 0                                                 81,1
# 1                                                 78,4
# 2                                                 85,6
# 3                                                 73,3
# 4                                                 76,5
# ..                                                 ...
# 375                                               83,2
# 376                                               74,1
# 377                                               88,4
# 378                                              103,8
# 379                                               93,0
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2008;[%]  \
# 0                                                 78,4
# 1                                                 78,8
# 2                                                 83,8
# 3                                                 75,2
# 4                                                 75,0
# ..                                                 ...
# 375                                               80,4
# 376                                               74,7
# 377                                               87,8
# 378                                              104,2
# 379                                               93,0
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2009;[%]  \
# 0                                                 79,3
# 1                                                 79,8
# 2                                                 86,3
# 3                                                 74,3
# 4                                                 75,6
# ..                                                 ...
# 375                                               80,8
# 376                                               75,4
# 377                                               88,4
# 378                                              104,7
# 379                                               93,1
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2010;[%]  \
# 0                                                 81,2
# 1                                                 82,4
# 2                                                 84,8
# 3                                                 75,6
# 4                                                 77,3
# ..                                                 ...
# 375                                               82,3
# 376                                               76,9
# 377                                               89,4
# 378                                              104,4
# 379                                               94,9
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2011;[%]  \
# 0                                                 81,0
# 1                                                 83,4
# 2                                                 83,5
# 3                                                 76,0
# 4                                                 78,3
# ..                                                 ...
# 375                                               82,2
# 376                                               78,4
# 377                                               87,8
# 378                                              103,8
# 379                                               99,3
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2012;[%]  \
# 0                                                 81,6
# 1                                                 83,1
# 2                                                 83,4
# 3                                                 77,7
# 4                                                 79,7
# ..                                                 ...
# 375                                               82,6
# 376                                               82,3
# 377                                               88,8
# 378                                              103,7
# 379                                               99,6
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2013;[%]  \
# 0                                                 83,3
# 1                                                 81,4
# 2                                                 85,6
# 3                                                 79,1
# 4                                                 78,4
# ..                                                 ...
# 375                                               83,3
# 376                                               80,5
# 377                                               90,1
# 378                                              103,9
# 379                                              100,7
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2014;[%]  \
# 0                                                 85,5
# 1                                                 82,4
# 2                                                 86,4
# 3                                                 78,5
# 4                                                 78,5
# ..                                                 ...
# 375                                               83,3
# 376                                               82,2
# 377                                               89,1
# 378                                              104,3
# 379                                              103,1
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2015;[%]  \
# 0                                                 85,5
# 1                                                 82,1
# 2                                                 87,1
# 3                                                 78,1
# 4                                                 80,1
# ..                                                 ...
# 375                                               83,0
# 376                                               82,4
# 377                                               87,8
# 378                                              105,6
# 379                                              104,7
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2016;[%]  \
# 0                                                 85,4
# 1                                                 83,0
# 2                                                 86,8
# 3                                                 78,9
# 4                                                 82,7
# ..                                                 ...
# 375                                               82,9
# 376                                               83,8
# 377                                               89,0
# 378                                              105,8
# 379                                              100,4
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2017;[%]  \
# 0                                                 86,2
# 1                                                 84,5
# 2                                                 86,5
# 3                                                 77,0
# 4                                                 83,0
# ..                                                 ...
# 375                                               83,1
# 376                                               80,9
# 377                                               88,3
# 378                                              104,5
# 379                                              100,2
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2018;[%]  \
# 0                                                 87,2
# 1                                                 83,3
# 2                                                 84,3
# 3                                                 78,9
# 4                                                 83,3
# ..                                                 ...
# 375                                               83,7
# 376                                               84,5
# 377                                               86,5
# 378                                              103,6
# 379                                               98,8
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2019;[%]  \
# 0                                                 87,7
# 1                                                 86,5
# 2                                                 85,5
# 3                                                 76,8
# 4                                                 85,1
# ..                                                 ...
# 375                                               84,2
# 376                                               83,4
# 377                                               89,3
# 378                                              104,4
# 379                                              100,8
#
#     przeciętne miesięczne wynagrodzenia brutto w relacji do średniej krajowej (Polska=100);2020;[%]  \
# 0                                                 88,5
# 1                                                 84,9
# 2                                                 86,2
# 3                                                 80,2
# 4                                                 89,3
# ..                                                 ...
# 375                                               84,7
# 376                                               85,3
# 377                                               90,0
# 378                                              103,1
# 379                                               99,9
#
#      Unnamed: 16
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 375          NaN
# 376          NaN
# 377          NaN
# 378          NaN
# 379          NaN
#
# [380 rows x 17 columns]

# %%
# Reverse columns 
id_vars = ['Kod', 'Nazwa']

value_vars = [col for col in wyna.columns if col.startswith('przeciętne miesięczne wynagrodzenia')]

# Unpivot the DataFrame
wyna = wyna.melt(id_vars=id_vars, value_vars=value_vars, var_name='TIME_PERIOD', value_name='Wynagrodzenie %')

# Extract the year from the 'TIME_PERIOD' column
wyna['TIME_PERIOD'] = wyna['TIME_PERIOD'].str.extract('(\d{4})')
wyna
# Out:
#           Kod                  Nazwa TIME_PERIOD Wynagrodzenie %
# 0      201000   Powiat bolesławiecki        2007            81,1
# 1      202000  Powiat dzierżoniowski        2007            78,4
# 2      203000       Powiat głogowski        2007            85,6
# 3      204000        Powiat górowski        2007            73,3
# 4      205000        Powiat jaworski        2007            76,5
# ...       ...                    ...         ...             ...
# 5315  3217000         Powiat wałecki        2020            84,7
# 5316  3218000         Powiat łobeski        2020            85,3
# 5317  3261000     Powiat m. Koszalin        2020            90,0
# 5318  3262000     Powiat m. Szczecin        2020           103,1
# 5319  3263000  Powiat m. Świnoujście        2020            99,9
#
# [5320 rows x 4 columns]

# %%
len(wyna['Kod'].unique())
# Out:
# 380

# %%
len(final['Kod'].unique())
# Out:
# 72

# %%
common_elements = set(wyna['Kod']).intersection(set(final['Kod']))
len(common_elements)
# Out:
# 0

# %%
# Create a new DataFrame with only 'Kod' and 'TIME_PERIOD' columns from merged_df
subset = wyna[['Kod', 'TIME_PERIOD', 'Wynagrodzenie %']].copy()

# Convert 'Kod' and 'TIME_PERIOD' to strings to ensure matching types for merge
subset['Kod'] = subset['Kod'].astype(str)
final['Kod'] = final['Kod'].astype(str)
subset['TIME_PERIOD'] = subset['TIME_PERIOD'].astype(str)
final['TIME_PERIOD'] = final['TIME_PERIOD'].astype(str)

# Merge df with subset on 'Kod' and 'TIME_PERIOD'
one_factor = final.merge(subset, on=['Kod', 'TIME_PERIOD'], how='left')
one_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod Wynagrodzenie %
# 0     11212100000             NaN
# 1     11212100000             NaN
# 2     11212100000             NaN
# 3     11212100000             NaN
# 4     11212100000             NaN
# ...           ...             ...
# 1031  71427300000             NaN
# 1032  71427300000             NaN
# 1033  71427300000             NaN
# 1034  71427300000             NaN
# 1035  71427300000             NaN
#
# [1036 rows x 16 columns]

# %%
# Check missing values
missing = one_factor[one_factor['Wynagrodzenie %'].isnull()]
missing
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod Wynagrodzenie %
# 0     11212100000             NaN
# 1     11212100000             NaN
# 2     11212100000             NaN
# 3     11212100000             NaN
# 4     11212100000             NaN
# ...           ...             ...
# 1031  71427300000             NaN
# 1032  71427300000             NaN
# 1033  71427300000             NaN
# 1034  71427300000             NaN
# 1035  71427300000             NaN
#
# [1036 rows x 16 columns]

# %%
# 
df['NUTS3 CODE'] = df['NUTS3 CODE'].astype(str).str.strip()
merged_df['NUTS3 CODE'] = merged_df['NUTS3 CODE'].astype(str).str.strip()

# Merging df with selected columns from merged_df
merged_result = df.merge(
    merged_df[['Kod', 'NUTS3 CODE']],
    on='NUTS3 CODE',
    how='left'
)

merged_df
# Out:
#     Unnamed: 0                                NUTS1 NUTS1 CODE  \
# 0          0.0                 MAKROREGION PÓŁNOCNY        PL6
# 1          1.0                 MAKROREGION WSCHODNI        PL8
# 2          2.0                 MAKROREGION PÓŁNOCNY        PL6
# 3          3.0               MAKROREGION POŁUDNIOWY        PL2
# 4          4.0                MAKROREGION CENTRALNY        PL7
# ..         ...                                  ...        ...
# 69        69.0        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 70        70.0  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 71        71.0      MAKROREGION POŁUDNIOWO-ZACHODNI        PL5
# 72         NaN  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 73         NaN  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
#
#                           NUTS2 NUTS2 CODE                          NUTS3  \
# 0     REGION KUJAWSKO-POMORSKIE       PL61           PODREGION WROCŁAWSKI
# 1              REGION PODLASKIE       PL84             PODREGION SUWALSKI
# 2    REGION WARMIŃSKO-MAZURSKIE       PL62           PODREGION OLSZTYŃSKI
# 3                REGION ŚLĄSKIE       PL22          PODREGION SOSNOWIECKI
# 4                REGION ŁÓDZKIE       PL71          PODREGION PIOTRKOWSKI
# ..                          ...        ...                            ...
# 69    REGION ZACHODNIOPOMORSKIE       PL42      PODREGION MIASTO SZCZECIN
# 70  REGION WARSZAWSKI STOŁECZNY       PL91      PODREGION MIASTO WARSZAWA
# 71          REGION DOLNOŚLĄSKIE       PL51       PODREGION MIASTO WROCŁAW
# 72  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION WARSZAWSKI ZACHODNI
# 73  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION WARSZAWSKI ZACHODNI
#
#    NUTS3 CODE          Kod
# 0       PL619  30210400000
# 1       PL843  62013900000
# 2       PL622  42815600000
# 3       PL22B  12415000000
# 4       PL713  51011700000
# ..        ...          ...
# 69      PL424  23216500000
# 70      PL911  71412800000
# 71      PL514  30210500000
# 72      PL913  71413000000
# 73      PL913  71413000000
#
# [74 rows x 8 columns]

# %%
mis =merged_result[merged_result['Kod'].isnull()]
mis
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, NUTS3 CODE, TIME_PERIOD, POP (THS), EMP (THS), EUR_HAB, EUR_HAB_EU27_2020, MIO_EUR, MIO_NAC, MIO_PPS_EU27_2020, PPS_EU27_2020_HAB, PPS_HAB_EU27_2020, GVA (MIO_EUR), GVA (MIO_NAC), Kod]
# Index: []

# %%
# Count the total number of nulls in each column of 'one_factor'
null_counts = one_factor.isna().sum()

# Display the count of nulls for each column
print(null_counts)
# Out:
# Unnamed: 0              0
# NUTS3 CODE              0
# TIME_PERIOD             0
# POP (THS)               0
# EMP (THS)               0
# EUR_HAB                 0
# EUR_HAB_EU27_2020       0
# MIO_EUR                 0
# MIO_NAC                 0
# MIO_PPS_EU27_2020       0
# PPS_EU27_2020_HAB       0
# PPS_HAB_EU27_2020       0
# GVA (MIO_EUR)           0
# GVA (MIO_NAC)           0
# Kod                     0
# Wynagrodzenie %      1036
# dtype: int64

# %% [markdown]
# #### Factor 1 - Relacja liczby studentów do ludności w wieku 19-24 lata, 2008 - 2020

# %%
pp = pd.read_csv('SZKO_4058_CTAB_20231123195156.csv', delimiter=';')
pp
# Out:
#             Kod                    Nazwa  \
# 0   11212000000      PODREGION KRAKOWSKI
# 1   11212100000  PODREGION MIASTO KRAKÓW
# 2   11212200000    PODREGION NOWOSĄDECKI
# 3   11212300000    PODREGION OŚWIĘCIMSKI
# 4   11212400000      PODREGION TARNOWSKI
# ..          ...                      ...
# 68  71422600000     PODREGION OSTROŁĘCKI
# 69  71422700000       PODREGION RADOMSKI
# 70  71427000000         PODREGION PŁOCKI
# 71  71427100000      PODREGION SIEDLECKI
# 72  71427300000    PODREGION ŻYRARDOWSKI
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2008;[-]  \
# 0                                                 1,5
# 1                                               255,5
# 2                                                17,1
# 3                                                 3,8
# 4                                                22,4
# ..                                                ...
# 68                                                8,8
# 69                                               25,9
# 70                                               33,6
# 71                                               31,5
# 72                                                6,3
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2009;[-]  \
# 0                                                 2,2
# 1                                               272,2
# 2                                                17,4
# 3                                                 4,5
# 4                                                23,2
# ..                                                ...
# 68                                                7,3
# 69                                               26,1
# 70                                               32,1
# 71                                               32,2
# 72                                                4,8
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2010;[-]  \
# 0                                                 2,5
# 1                                               254,7
# 2                                                18,0
# 3                                                 5,0
# 4                                                21,8
# ..                                                ...
# 68                                                7,1
# 69                                               27,2
# 70                                               31,1
# 71                                               34,4
# 72                                                5,3
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2011;[-]  \
# 0                                                 2,5
# 1                                               272,8
# 2                                                16,5
# 3                                                 4,4
# 4                                                18,8
# ..                                                ...
# 68                                                5,7
# 69                                               25,0
# 70                                               29,7
# 71                                               30,9
# 72                                                6,6
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2012;[-]  \
# 0                                                 2,2
# 1                                               296,1
# 2                                                14,7
# 3                                                 4,7
# 4                                                16,7
# ..                                                ...
# 68                                                4,4
# 69                                               24,1
# 70                                               27,8
# 71                                               27,7
# 72                                                5,9
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2013;[-]  \
# 0                                                 2,4
# 1                                               301,5
# 2                                                13,0
# 3                                                 4,1
# 4                                                15,8
# ..                                                ...
# 68                                                3,3
# 69                                               21,9
# 70                                               25,9
# 71                                               25,0
# 72                                                4,4
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2014;[-]  \
# 0                                                 2,4
# 1                                               320,6
# 2                                                11,5
# 3                                                 4,2
# 4                                                14,9
# ..                                                ...
# 68                                                2,9
# 69                                               20,3
# 70                                               25,2
# 71                                               23,4
# 72                                                3,1
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2015;[-]  \
# 0                                                 2,1
# 1                                               351,0
# 2                                                10,6
# 3                                                 3,9
# 4                                                13,7
# ..                                                ...
# 68                                                2,4
# 69                                               19,4
# 70                                               23,9
# 71                                               20,6
# 72                                                3,2
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2016;[-]  \
# 0                                                 2,0
# 1                                               364,6
# 2                                                 9,9
# 3                                                 4,0
# 4                                                13,4
# ..                                                ...
# 68                                                2,1
# 69                                               18,2
# 70                                               23,4
# 71                                               19,1
# 72                                                3,8
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2017;[-]  \
# 0                                                 0,2
# 1                                               352,1
# 2                                                10,2
# 3                                                 4,7
# 4                                                14,4
# ..                                                ...
# 68                                                2,0
# 69                                               16,4
# 70                                               23,5
# 71                                               19,6
# 72                                                5,5
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2018;[-]  \
# 0                                                 2,1
# 1                                               351,7
# 2                                                10,3
# 3                                                 5,5
# 4                                                14,6
# ..                                                ...
# 68                                                1,8
# 69                                               15,8
# 70                                               22,9
# 71                                               19,9
# 72                                                6,7
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2019;[-]  \
# 0                                                 2,3
# 1                                               342,6
# 2                                                10,9
# 3                                                 5,7
# 4                                                15,0
# ..                                                ...
# 68                                                1,9
# 69                                               17,0
# 70                                               22,4
# 71                                               20,7
# 72                                                2,1
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2020;[-]  \
# 0                                                 2,5
# 1                                               253,8
# 2                                                13,7
# 3                                                 6,7
# 4                                                16,3
# ..                                                ...
# 68                                                2,4
# 69                                               18,6
# 70                                               23,2
# 71                                               23,3
# 72                                                7,2
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2021;[-]  \
# 0                                                 2,4
# 1                                               282,9
# 2                                                16,6
# 3                                                 6,4
# 4                                                17,0
# ..                                                ...
# 68                                                2,7
# 69                                               20,4
# 70                                               22,0
# 71                                               23,7
# 72                                                9,1
#
#    relacja liczby studentów do ludności w wieku 19-24 lata;2022;[-]  \
# 0                                                 2,5
# 1                                               311,7
# 2                                                22,1
# 3                                                 6,1
# 4                                                16,0
# ..                                                ...
# 68                                                2,8
# 69                                               21,7
# 70                                               20,8
# 71                                               23,3
# 72                                               10,4
#
#     Unnamed: 17
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 68          NaN
# 69          NaN
# 70          NaN
# 71          NaN
# 72          NaN
#
# [73 rows x 18 columns]

# %%
id_vars = ['Kod', 'Nazwa']

# Specify the value_vars, which are the columns to melt
# These columns start with 'relacja liczby studentów do ludności w wieku 19-24 lata'
value_vars = [col for col in pp.columns if col.startswith('relacja liczby studentów do ludności w wieku 19-24 lata')]

# Performing the melt operation
pp = pp.melt(id_vars=id_vars, value_vars=value_vars, var_name='TIME_PERIOD', value_name='Studenci do Ludności w wieku 19-24')

# Extracting the year from the 'TIME_PERIOD' column
# The year is between two semicolons (;), so we split and get the second element ([1])
pp['TIME_PERIOD'] = pp['TIME_PERIOD'].apply(lambda x: x.split(';')[1])

# Verify the result
pp
# Out:
#               Kod                    Nazwa TIME_PERIOD  \
# 0     11212000000      PODREGION KRAKOWSKI        2008
# 1     11212100000  PODREGION MIASTO KRAKÓW        2008
# 2     11212200000    PODREGION NOWOSĄDECKI        2008
# 3     11212300000    PODREGION OŚWIĘCIMSKI        2008
# 4     11212400000      PODREGION TARNOWSKI        2008
# ...           ...                      ...         ...
# 1090  71422600000     PODREGION OSTROŁĘCKI        2022
# 1091  71422700000       PODREGION RADOMSKI        2022
# 1092  71427000000         PODREGION PŁOCKI        2022
# 1093  71427100000      PODREGION SIEDLECKI        2022
# 1094  71427300000    PODREGION ŻYRARDOWSKI        2022
#
#      Studenci do Ludności w wieku 19-24
# 0                                   1,5
# 1                                 255,5
# 2                                  17,1
# 3                                   3,8
# 4                                  22,4
# ...                                 ...
# 1090                                2,8
# 1091                               21,7
# 1092                               20,8
# 1093                               23,3
# 1094                               10,4
#
# [1095 rows x 4 columns]

# %%
pp['Studenci do Ludności w wieku 19-24'] = pp['Studenci do Ludności w wieku 19-24'].str.replace(',', '.')
pp['Studenci do Ludności w wieku 19-24'] = pp['Studenci do Ludności w wieku 19-24'].astype(float)
nan_rows = pp[pp['Studenci do Ludności w wieku 19-24'].isna()]
nan_rows
# Out:
# Empty DataFrame
# Columns: [Kod, Nazwa, TIME_PERIOD, Studenci do Ludności w wieku 19-24]
# Index: []

# %%
# Create a new DataFrame with only 'Kod' and 'TIME_PERIOD' columns from merged_df
subset = pp[['Kod', 'TIME_PERIOD', 'Studenci do Ludności w wieku 19-24']].copy()

# Convert 'Kod' and 'TIME_PERIOD' to strings to ensure matching types for merge
subset['Kod'] = subset['Kod'].astype(str)
final['Kod'] = final['Kod'].astype(str)
subset['TIME_PERIOD'] = subset['TIME_PERIOD'].astype(str)
final['TIME_PERIOD'] = final['TIME_PERIOD'].astype(str)

# Merge df with subset on 'Kod' and 'TIME_PERIOD'
one_factor = final.merge(subset, on=['Kod', 'TIME_PERIOD'], how='left')
one_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod  Studenci do Ludności w wieku 19-24
# 0     11212100000                                 NaN
# 1     11212100000                               255.5
# 2     11212100000                               272.2
# 3     11212100000                               254.7
# 4     11212100000                               272.8
# ...           ...                                 ...
# 1031  71427300000                                 3.8
# 1032  71427300000                                 5.5
# 1033  71427300000                                 6.7
# 1034  71427300000                                 2.1
# 1035  71427300000                                 7.2
#
# [1036 rows x 16 columns]

# %%
one_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod  Studenci do Ludności w wieku 19-24
# 0     11212100000                                 NaN
# 1     11212100000                               255.5
# 2     11212100000                               272.2
# 3     11212100000                               254.7
# 4     11212100000                               272.8
# ...           ...                                 ...
# 1031  71427300000                                 3.8
# 1032  71427300000                                 5.5
# 1033  71427300000                                 6.7
# 1034  71427300000                                 2.1
# 1035  71427300000                                 7.2
#
# [1036 rows x 16 columns]

# %%
# Count the total number of nulls in each column of 'one_factor'
null_counts = one_factor.isnull().sum()

null_counts
# Out:
# Unnamed: 0                             0
# NUTS3 CODE                             0
# TIME_PERIOD                            0
# POP (THS)                              0
# EMP (THS)                              0
# EUR_HAB                                0
# EUR_HAB_EU27_2020                      0
# MIO_EUR                                0
# MIO_NAC                                0
# MIO_PPS_EU27_2020                      0
# PPS_EU27_2020_HAB                      0
# PPS_HAB_EU27_2020                      0
# GVA (MIO_EUR)                          0
# GVA (MIO_NAC)                          0
# Kod                                    0
# Studenci do Ludności w wieku 19-24    74
# dtype: int64

# %%
# Filter the dataframe for rows where 'Studenci do Ludności w wieku 19-24' is zero
zero_values = pp[pp['Studenci do Ludności w wieku 19-24'] == 0]

# Display the corresponding 'Nazwa' values for these rows
print(zero_values[['Kod', 'Nazwa', 'Studenci do Ludności w wieku 19-24']])
# Out:
#               Kod                 Nazwa  Studenci do Ludności w wieku 19-24
# 175   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 540   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 557   51011500000      PODREGION ŁÓDZKI                                 0.0
# 613   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 630   51011500000      PODREGION ŁÓDZKI                                 0.0
# 686   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 703   51011500000      PODREGION ŁÓDZKI                                 0.0
# 743   12415100000       PODREGION TYSKI                                 0.0
# 759   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 776   51011500000      PODREGION ŁÓDZKI                                 0.0
# 816   12415100000       PODREGION TYSKI                                 0.0
# 832   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 849   51011500000      PODREGION ŁÓDZKI                                 0.0
# 889   12415100000       PODREGION TYSKI                                 0.0
# 905   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 922   51011500000      PODREGION ŁÓDZKI                                 0.0
# 962   12415100000       PODREGION TYSKI                                 0.0
# 978   30210400000  PODREGION WROCŁAWSKI                                 0.0
# 995   51011500000      PODREGION ŁÓDZKI                                 0.0
# 1035  12415100000       PODREGION TYSKI                                 0.0
# 1051  30210400000  PODREGION WROCŁAWSKI                                 0.0
# 1068  51011500000      PODREGION ŁÓDZKI                                 0.0

# %%
# Count NaNs in 'Studenci do Ludności w wieku 19-24'
nan_count = one_factor['Studenci do Ludności w wieku 19-24'].isna().sum()
print(f"Number of NaNs in 'Studenci do Ludności w wieku 19-24': {nan_count}")

# Count zeros in 'Studenci do Ludności w wieku 19-24'
zero_count = (one_factor['Studenci do Ludności w wieku 19-24'] == 0).sum()
print(f"Number of zeros in 'Studenci do Ludności w wieku 19-24': {zero_count}")
# Out:
# Number of NaNs in 'Studenci do Ludności w wieku 19-24': 74
# Number of zeros in 'Studenci do Ludności w wieku 19-24': 23

# %%
# Filter the dataframe to find rows where 'Studenci do Ludności w wieku 19-24' is NaN
nan_rows = one_factor[one_factor['Studenci do Ludności w wieku 19-24'].isna()]

nan_rows
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007      756.3      428.6    13200
# 14            14      PL214        2007      665.9      228.6     5500
# 28            28      PL217        2007      459.6      159.2     5400
# 42            42      PL218        2007      512.7      185.1     5200
# 56            56      PL219        2007      330.1      110.6     4800
# ...          ...        ...         ...        ...        ...      ...
# 966          952      PL922        2007      342.3      122.5     6100
# 980          966      PL923        2007      334.3      137.6    11000
# 994          980      PL924        2007      383.8      134.1     5700
# 1008         994      PL925        2007      420.3      164.3     5900
# 1022        1008      PL926        2007      254.8      102.8     6700
#
#       EUR_HAB_EU27_2020  MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54  9982.27  37769.90           16084.62
# 14                   22  3673.14  13898.04            5918.59
# 28                   22  2472.17   9353.97            3983.46
# 42                   21  2685.66  10161.73            4327.45
# 56                   20  1592.80   6026.69            2566.51
# ...                 ...      ...       ...                ...
# 966                  25  2088.21   7901.15            3364.77
# 980                  45  3661.63  13854.50            5900.05
# 994                  23  2203.28   8336.53            3550.18
# 1008                 24  2467.03   9334.49            3975.17
# 1022                 27  1701.21   6436.87            2741.19
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 14                 8900                 36        3205.86          12130
# 28                 8700                 35        2157.68           8164
# 42                 8400                 34        2344.00           8869
# 56                 7800                 32        1390.17           5260
# ...                 ...                ...            ...            ...
# 966                9800                 40        1822.55           6896
# 980               17600                 72        3195.81          12092
# 994                9300                 38        1922.99           7276
# 1008               9500                 39        2153.18           8147
# 1022              10800                 44        1484.79           5618
#
#               Kod  Studenci do Ludności w wieku 19-24
# 0     11212100000                                 NaN
# 14    11212000000                                 NaN
# 28    11212400000                                 NaN
# 42    11212200000                                 NaN
# 56    11216900000                                 NaN
# ...           ...                                 ...
# 966   71422500000                                 NaN
# 980   71427000000                                 NaN
# 994   71422600000                                 NaN
# 1008  71427100000                                 NaN
# 1022  71427300000                                 NaN
#
# [74 rows x 16 columns]

# %% [markdown]
# Missing values are for 2007 and there are 0.0 values for 3 regions that contribute to thhose 73 missing values.

# %% [markdown]
# #### Factor 2 - population structure by gender 2014 - 2022
#
# Od roku 2020 bazą wyjściową bilansu stanu i struktury ludności są wyniki NSP 2021. W związku z tym dane jak i wskaźniki odnoszące się do liczby i struktury ludności (płeć, grupy wieku) od 2020 roku zostały przeliczone zgodnie z bilansem przygotowanym w oparciu o wyniki NSP 2021. Bilanse liczby i struktury ludności w gminach imiennie opracowane w oparciu o wyniki Narodowych Spisów Powszechnych z uwzględnieniem zmian spowodowanych ruchem naturalnym (urodzenia i zgony), migracjami ludności (na pobyt stały i czasowy) oraz przemieszczeniami związanymi ze zmianami administracyjnymi. Dane o ludności w miejscowościach na podstawie rejestru PESEL. Dane o zarejestrowanych małżeństwach, urodzeniach i zgonach pochodzące ze sprawozdawczości urzędów stanu cywilnego. Dane o orzeczonych rozwodach i separacjach pochodzące ze sprawozdawczości sądów. Dane o migracjach wewnętrznych i zagranicznych na pobyt stały pochodzą z Ministerstwa Spraw Wewnętrznych i Administracji. Prognoza ludności na podstawie badania GUS.

# %%
file_path = 'LUDN_2730_XTAB_20231125152006.xlsx'

# Read the specific sheet 'TABLICA'
tablica_df = pd.read_excel(file_path, sheet_name='TABLICA')

tablica_df = tablica_df.copy()

# %%
# Cleaning the dataset
men_columns = tablica_df.columns[4:12]  # Starting from 2014
women_columns = tablica_df.columns[15:23]  # Starting from 2014
years = tablica_df.iloc[2, 4:12].values  # Getting the years starting from 2014

# Create a DataFrame for men
df_men = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=men_columns, var_name='TIME_PERIOD', value_name='mężczyźni')
df_men['TIME_PERIOD'] = df_men['TIME_PERIOD'].map(dict(zip(men_columns, years)))

# Create a DataFrame for women
df_women = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=women_columns, var_name='TIME_PERIOD', value_name='kobiety')
df_women['TIME_PERIOD'] = df_women['TIME_PERIOD'].map(dict(zip(women_columns, years)))

# Merge the men and women DataFrames
final_df = pd.merge(df_men, df_women, on=['Kod', 'Nazwa', 'TIME_PERIOD'])

# Select only the relevant columns
final_df = final_df[['Kod', 'Nazwa', 'mężczyźni', 'kobiety', 'TIME_PERIOD']]

final_df
# Out:
# /var/folders/vn/7p3t4_3n02gcv591cgws1gw80000gn/T/ipykernel_18152/3348879281.py:7: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_men = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=men_columns, var_name='TIME_PERIOD', value_name='mężczyźni')
# /var/folders/vn/7p3t4_3n02gcv591cgws1gw80000gn/T/ipykernel_18152/3348879281.py:11: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_women = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=women_columns, var_name='TIME_PERIOD', value_name='kobiety')
#               Kod                  Nazwa mężczyźni kobiety TIME_PERIOD
# 0             NaN                    NaN       NaN     NaN        2014
# 1             NaN                    NaN       NaN     NaN        2014
# 2             NaN                    NaN       NaN    2014        2014
# 3             NaN                    NaN       NaN  [lata]        2014
# 4             NaN                    NaN       NaN     NaN        2014
# ..            ...                    ...       ...     ...         ...
# 707  7.142260e+10   PODREGION OSTROŁĘCKI      70.1    80.1        2021
# 708  7.142270e+10     PODREGION RADOMSKI      70.7    79.8        2021
# 709  7.142700e+10       PODREGION PŁOCKI      70.4    78.8        2021
# 710  7.142710e+10    PODREGION SIEDLECKI      70.4    79.6        2021
# 711  7.142730e+10  PODREGION ŻYRARDOWSKI      69.7      78        2021
#
# [712 rows x 5 columns]

# %%
# Drop rows where 'Kod' is NaN
final_df = final_df.dropna(subset=['Kod'])

final_df
# Out:
#               Kod                    Nazwa mężczyźni kobiety TIME_PERIOD
# 16   1.121200e+10      PODREGION KRAKOWSKI     74.97   82.12        2014
# 17   1.121210e+10  PODREGION MIASTO KRAKÓW     76.75   82.45        2014
# 18   1.121220e+10    PODREGION NOWOSĄDECKI     74.99   82.37        2014
# 19   1.121230e+10    PODREGION OŚWIĘCIMSKI     73.97   82.22        2014
# 20   1.121240e+10      PODREGION TARNOWSKI     75.67   82.86        2014
# ..            ...                      ...       ...     ...         ...
# 707  7.142260e+10     PODREGION OSTROŁĘCKI      70.1    80.1        2021
# 708  7.142270e+10       PODREGION RADOMSKI      70.7    79.8        2021
# 709  7.142700e+10         PODREGION PŁOCKI      70.4    78.8        2021
# 710  7.142710e+10      PODREGION SIEDLECKI      70.4    79.6        2021
# 711  7.142730e+10    PODREGION ŻYRARDOWSKI      69.7      78        2021
#
# [584 rows x 5 columns]

# %%
# Rename columns
final_df = final_df.rename(columns={'mężczyźni': 'population men', 'kobiety': 'population women'})
final_df['Kod'] = final_df['Kod'].astype(int).astype(str)

# Convert 'Kod' and 'TIME_PERIOD' to strings to ensure matching types for merge
final_df['Kod'] = final_df['Kod'].astype(str)
one_factor['Kod'] = one_factor['Kod'].astype(str)
final_df['TIME_PERIOD'] = final_df['TIME_PERIOD'].astype(str)
one_factor['TIME_PERIOD'] = one_factor['TIME_PERIOD'].astype(str)

# First, convert 'Kod' to float, then to integer, and finally to string
final_df['Kod'] = final_df['Kod'].astype(float).astype(int).astype(str)

# Ensure 'Kod' in one_factor is also in string format
one_factor['Kod'] = one_factor['Kod'].astype(str)

# Perform the merge
second_factor = pd.merge(one_factor, final_df[['Kod', 'TIME_PERIOD', 'population men', 'population women']], on=['Kod', 'TIME_PERIOD'], how='left')

second_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod  Studenci do Ludności w wieku 19-24 population men  \
# 0     11212100000                                 NaN            NaN
# 1     11212100000                               255.5            NaN
# 2     11212100000                               272.2            NaN
# 3     11212100000                               254.7            NaN
# 4     11212100000                               272.8            NaN
# ...           ...                                 ...            ...
# 1031  71427300000                                 3.8              0
# 1032  71427300000                                 5.5              0
# 1033  71427300000                                 6.7           71.9
# 1034  71427300000                                 2.1           72.2
# 1035  71427300000                                 7.2           70.9
#
#      population women
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1031                0
# 1032                0
# 1033             80.8
# 1034             80.6
# 1035             79.3
#
# [1036 rows x 18 columns]

# %%
# Count the total number of nulls in each column of 'one_factor'
null_counts = second_factor.isna().sum()

# Display the count of nulls for each column
null_counts
# Out:
# Unnamed: 0                              0
# NUTS3 CODE                              0
# TIME_PERIOD                             0
# POP (THS)                               0
# EMP (THS)                               0
# EUR_HAB                                 0
# EUR_HAB_EU27_2020                       0
# MIO_EUR                                 0
# MIO_NAC                                 0
# MIO_PPS_EU27_2020                       0
# PPS_EU27_2020_HAB                       0
# PPS_HAB_EU27_2020                       0
# GVA (MIO_EUR)                           0
# GVA (MIO_NAC)                           0
# Kod                                     0
# Studenci do Ludności w wieku 19-24     74
# population men                        518
# population women                      518
# dtype: int64

# %%
# Filter the dataframe to find rows NaNa 
nan_rows = second_factor[second_factor['population women'].isna()]

nan_rows['TIME_PERIOD']
# Out:
# 0       2007
# 1       2008
# 2       2009
# 3       2010
# 4       2011
#         ...
# 1024    2009
# 1025    2010
# 1026    2011
# 1027    2012
# 1028    2013
# Name: TIME_PERIOD, Length: 518, dtype: object

# %% [markdown]
# Misssing values are for 2007 - 2013 that contribute to this high values of 511 being nans.

# %% [markdown]
# ### 3. Factor

# %%
f3 = pd.read_excel('WYNA_2497_XTAB_20231123194522.xlsx')
f3
# Out:
#             Kod                    Nazwa     2002     2003     2004     2005  \
# 0   11212000000      PODREGION KRAKOWSKI  2005.98  2043.51  2091.61  2158.55
# 1   11212100000  PODREGION MIASTO KRAKÓW  2300.64  2324.15  2463.26  2579.09
# 2   11212200000    PODREGION NOWOSĄDECKI  1813.69  1895.88  1934.66  2014.91
# 3   11212300000    PODREGION OŚWIĘCIMSKI  1923.59  2005.17  2135.88  2182.59
# 4   11212400000      PODREGION TARNOWSKI  1757.93  1852.60  1916.03  1960.45
# ..          ...                      ...      ...      ...      ...      ...
# 68  71422600000     PODREGION OSTROŁĘCKI  1951.67  2005.94  2102.36  2157.11
# 69  71422700000       PODREGION RADOMSKI  2017.96  2078.24  2138.75  2194.24
# 70  71427000000         PODREGION PŁOCKI  2461.48  2526.25  2592.58  2686.65
# 71  71427100000      PODREGION SIEDLECKI  1944.77  2011.01  2091.84  2130.93
# 72  71427300000    PODREGION ŻYRARDOWSKI  2267.36  2383.42  2396.72  2475.54
#
#        2006     2007     2008     2009  ...     2013     2014     2015  \
# 0   2244.29  2472.93  2700.24  2853.76  ...  3436.01  3552.25  3775.55
# 1   2753.21  2995.18  3259.63  3423.56  ...  3997.80  4152.52  4431.17
# 2   2086.05  2283.30  2479.05  2601.94  ...  2982.13  3077.10  3188.12
# 3   2292.52  2503.35  2709.07  2847.04  ...  3269.93  3384.20  3488.71
# 4   2085.42  2299.90  2529.45  2697.36  ...  3177.39  3264.92  3392.08
# ..      ...      ...      ...      ...  ...      ...      ...      ...
# 68  2276.55  2471.39  2694.14  2880.44  ...  3400.61  3543.29  3586.70
# 69  2269.29  2469.94  2732.60  2911.12  ...  3466.95  3580.06  3667.17
# 70  2816.19  3126.02  3408.41  3544.66  ...  4227.84  4327.54  4467.57
# 71  2228.81  2397.42  2643.58  2793.20  ...  3269.56  3413.81  3562.44
# 72  2529.15  2761.17  2981.45  3196.91  ...  3689.22  3905.08  3978.44
#
#        2016     2017     2018     2019     2020     2021     2022
# 0   4009.95  4293.01  4622.58  4907.62  5190.51  5321.38  6057.05
# 1   4635.26  4966.20  5368.39  5878.79  6482.24  7203.41  8157.43
# 2   3293.79  3472.91  3720.42  3964.93  4260.25  4672.68  5234.58
# 3   3637.14  3861.09  4146.85  4460.97  4773.53  5216.18  5762.88
# 4   3502.00  3670.53  3879.02  4622.36  5009.76  5400.26  5994.91
# ..      ...      ...      ...      ...      ...      ...      ...
# 68  3733.47  3952.04  4175.95  4444.58  4809.06  5218.29  5871.61
# 69  3788.20  4029.81  4266.89  4546.40  4852.53  5441.53  6017.31
# 70  4595.35  4791.24  5083.15  5437.92  5829.84  6408.11  7120.05
# 71  3646.06  3830.06  4097.88  4421.48  4825.59  5232.74  5777.47
# 72  4111.52  4341.10  4582.52  4902.14  5319.27  5864.86  6560.85
#
# [73 rows x 23 columns]

# %%
# List of year columns to be melted (from 2008 to 2023)
year_columns = [str(year) for year in range(2008, 2023)]

# Melting the DataFrame
melted_f3 = f3.melt(id_vars=['Kod', 'Nazwa'], value_vars=year_columns, var_name='TIME_PERIOD', value_name='Mean_salary')

# Display the transformed DataFrame
melted_f3.isnull().sum()
# Out:
# Kod            0
# Nazwa          0
# TIME_PERIOD    0
# Mean_salary    0
# dtype: int64

# %%
# Convert 'Kod' and 'TIME_PERIOD' to strings to ensure matching types for merge
melted_f3['Kod'] = melted_f3['Kod'].astype(str)
second_factor['Kod'] = second_factor['Kod'].astype(str)
melted_f3['TIME_PERIOD'] = melted_f3['TIME_PERIOD'].astype(str)
second_factor['TIME_PERIOD'] = second_factor['TIME_PERIOD'].astype(str)

# First, convert 'Kod' to float, then to integer, and finally to string
melted_f3['Kod'] = melted_f3['Kod'].astype(float).astype(int).astype(str)

# Ensure 'Kod' in one_factor is also in string format
second_factor['Kod'] = second_factor['Kod'].astype(str)

# Perform the merge
third_factor = pd.merge(second_factor, melted_f3[['Kod', 'TIME_PERIOD', 'Mean_salary']], on=['Kod', 'TIME_PERIOD'], how='left')

third_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod  Studenci do Ludności w wieku 19-24 population men  \
# 0     11212100000                                 NaN            NaN
# 1     11212100000                               255.5            NaN
# 2     11212100000                               272.2            NaN
# 3     11212100000                               254.7            NaN
# 4     11212100000                               272.8            NaN
# ...           ...                                 ...            ...
# 1031  71427300000                                 3.8              0
# 1032  71427300000                                 5.5              0
# 1033  71427300000                                 6.7           71.9
# 1034  71427300000                                 2.1           72.2
# 1035  71427300000                                 7.2           70.9
#
#      population women  Mean_salary
# 0                 NaN          NaN
# 1                 NaN      3259.63
# 2                 NaN      3423.56
# 3                 NaN      3543.43
# 4                 NaN      3722.48
# ...               ...          ...
# 1031                0      4111.52
# 1032                0      4341.10
# 1033             80.8      4582.52
# 1034             80.6      4902.14
# 1035             79.3      5319.27
#
# [1036 rows x 19 columns]

# %%
third_factor.isnull().sum()
# Out:
# Unnamed: 0                              0
# NUTS3 CODE                              0
# TIME_PERIOD                             0
# POP (THS)                               0
# EMP (THS)                               0
# EUR_HAB                                 0
# EUR_HAB_EU27_2020                       0
# MIO_EUR                                 0
# MIO_NAC                                 0
# MIO_PPS_EU27_2020                       0
# PPS_EU27_2020_HAB                       0
# PPS_HAB_EU27_2020                       0
# GVA (MIO_EUR)                           0
# GVA (MIO_NAC)                           0
# Kod                                     0
# Studenci do Ludności w wieku 19-24     74
# population men                        518
# population women                      518
# Mean_salary                            74
# dtype: int64

# %%
# Filter the dataframe
nan_rows = third_factor[third_factor['Mean_salary'].isna()]

nan_rows['TIME_PERIOD'].unique()
# Out:
# array(['2007'], dtype=object)

# %% [markdown]
# Missinbg values for 2007 year that contribute to 73 empty rows

# %% [markdown]
# ### 4. Factor - Studenci ogółem 2012 - 2020

# %%
f4 = pd.read_csv('SZKO_3226_CTAB_20231125151701.csv', delimiter = ';')
f4 = f4.copy()
f4
# Out:
#             Kod                    Nazwa  studenci ogółem;2012;[osoba]  \
# 0   11212000000      PODREGION KRAKOWSKI                          1338
# 1   11212100000  PODREGION MIASTO KRAKÓW                        181924
# 2   11212200000    PODREGION NOWOSĄDECKI                          7410
# 3   11212300000    PODREGION OŚWIĘCIMSKI                          2151
# 4   11212400000      PODREGION TARNOWSKI                          7127
# ..          ...                      ...                           ...
# 68  71422600000     PODREGION OSTROŁĘCKI                          1587
# 69  71422700000       PODREGION RADOMSKI                         13257
# 70  71427000000         PODREGION PŁOCKI                          7943
# 71  71427100000      PODREGION SIEDLECKI                         10727
# 72  71427300000    PODREGION ŻYRARDOWSKI                          1235
#
#     studenci ogółem;2013;[osoba]  studenci ogółem;2014;[osoba]  \
# 0                           1423                          1432
# 1                         170519                        165857
# 2                           6434                          5592
# 3                           1839                          1824
# 4                           6566                          6016
# ..                           ...                           ...
# 68                          1177                          1013
# 69                         11808                         10654
# 70                          7296                          6887
# 71                          9506                          8705
# 72                           914                           616
#
#     studenci ogółem;2015;[osoba]  studenci ogółem;2016;[osoba]  \
# 0                           1216                          1117
# 1                         160808                        154332
# 2                           5027                          4547
# 3                           1588                          1568
# 4                           5397                          5045
# ..                           ...                           ...
# 68                           822                           676
# 69                          9844                          8856
# 70                          6363                          5990
# 71                          7419                          6586
# 72                           632                           718
#
#     studenci ogółem;2017;[osoba]  studenci ogółem;2018;[osoba]  \
# 0                            113                          1100
# 1                         143613                        134969
# 2                           4542                          4450
# 3                           1764                          1961
# 4                           5178                          5084
# ..                           ...                           ...
# 68                           619                           553
# 69                          7621                          6990
# 70                          5777                          5345
# 71                          6446                          6257
# 72                           990                          1146
#
#     studenci ogółem;2019;[osoba]  studenci ogółem;2020;[osoba]  \
# 0                           1162                          1206
# 1                         129887                        130428
# 2                           4619                          5399
# 3                           1969                          2133
# 4                           5035                          4956
# ..                           ...                           ...
# 68                           558                           622
# 69                          7219                          7028
# 70                          4994                          4578
# 71                          6252                          6298
# 72                           344                          1129
#
#     studenci ogółem;2021;[osoba]  studenci ogółem;2022;[osoba]  Unnamed: 13
# 0                           1158                          1205          NaN
# 1                         130360                        129357          NaN
# 2                           6471                          8511          NaN
# 3                           2018                          1917          NaN
# 4                           5038                          4627          NaN
# ..                           ...                           ...          ...
# 68                           693                           702          NaN
# 69                          7561                          7926          NaN
# 70                          4235                          3933          NaN
# 71                          6245                          6008          NaN
# 72                          1396                          1575          NaN
#
# [73 rows x 14 columns]

# %%
# Selecting the columns for unpivoting
id_vars = ['Kod', 'Nazwa']
value_vars = [col for col in f4.columns if col.startswith('studenci ogółem')]

# Unpivot the DataFrame
f4 = f4.melt(id_vars=id_vars, value_vars=value_vars, var_name='TIME_PERIOD', value_name='Studenci')

# Extract the year from the 'TIME_PERIOD' column
f4['TIME_PERIOD'] = f4['TIME_PERIOD'].str.extract('(\d{4})')

print(f4.head())
# Out:
#            Kod                    Nazwa TIME_PERIOD  Studenci
# 0  11212000000      PODREGION KRAKOWSKI        2012      1338
# 1  11212100000  PODREGION MIASTO KRAKÓW        2012    181924
# 2  11212200000    PODREGION NOWOSĄDECKI        2012      7410
# 3  11212300000    PODREGION OŚWIĘCIMSKI        2012      2151
# 4  11212400000      PODREGION TARNOWSKI        2012      7127

# %%
# Convert 'Kod' and 'TIME_PERIOD' to strings to ensure matching types for merge
f4['Kod'] = f4['Kod'].astype(str)

# First, convert 'Kod' to float, then to integer, and finally to string
#f4['Kod'] = f4['Kod'].astype(float).astype(int).astype(str)

# Ensure 'Kod' in one_factor is also in string format
third_factor['Kod'] = third_factor['Kod'].astype(str)

# Perform the merge
forth_factor = pd.merge(third_factor, f4[['Kod', 'TIME_PERIOD', 'Studenci']], on=['Kod', 'TIME_PERIOD'], how='left')

forth_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  \
# 0                    54   9982.27  37769.90           16084.62
# 1                    60  11393.55  40015.30           16853.02
# 2                    53   9755.34  42217.21           17053.12
# 3                    58  11017.52  44011.69           18453.85
# 4                    60  11581.62  47723.22           19738.61
# ...                 ...       ...       ...                ...
# 1031                 35   2556.74  11155.56            4471.49
# 1032                 36   2739.42  11661.73            4595.52
# 1033                 36   2857.49  12177.18            4722.54
# 1034                 37   3040.11  13065.19            5001.82
# 1035                 40   3093.94  13746.36            5155.48
#
#       PPS_EU27_2020_HAB  PPS_HAB_EU27_2020  GVA (MIO_EUR)  GVA (MIO_NAC)  \
# 0                 21300                 87        8712.37          32965
# 1                 22300                 88        9939.92          34910
# 2                 22400                 93        8659.07          37473
# 3                 24400                 98        9594.71          38328
# 4                 26000                101       10093.43          41591
# ...                 ...                ...            ...            ...
# 1031              17200                 61        2272.64           9916
# 1032              17700                 60        2425.65          10326
# 1033              18200                 60        2502.64          10665
# 1034              19300                 62        2671.96          11483
# 1035              19900                 66        2725.19          12108
#
#               Kod  Studenci do Ludności w wieku 19-24 population men  \
# 0     11212100000                                 NaN            NaN
# 1     11212100000                               255.5            NaN
# 2     11212100000                               272.2            NaN
# 3     11212100000                               254.7            NaN
# 4     11212100000                               272.8            NaN
# ...           ...                                 ...            ...
# 1031  71427300000                                 3.8              0
# 1032  71427300000                                 5.5              0
# 1033  71427300000                                 6.7           71.9
# 1034  71427300000                                 2.1           72.2
# 1035  71427300000                                 7.2           70.9
#
#      population women  Mean_salary  Studenci
# 0                 NaN          NaN       NaN
# 1                 NaN      3259.63       NaN
# 2                 NaN      3423.56       NaN
# 3                 NaN      3543.43       NaN
# 4                 NaN      3722.48       NaN
# ...               ...          ...       ...
# 1031                0      4111.52     718.0
# 1032                0      4341.10     990.0
# 1033             80.8      4582.52    1146.0
# 1034             80.6      4902.14     344.0
# 1035             79.3      5319.27    1129.0
#
# [1036 rows x 20 columns]

# %%
forth_factor.isnull().sum()
# Out:
# Unnamed: 0                              0
# NUTS3 CODE                              0
# TIME_PERIOD                             0
# POP (THS)                               0
# EMP (THS)                               0
# EUR_HAB                                 0
# EUR_HAB_EU27_2020                       0
# MIO_EUR                                 0
# MIO_NAC                                 0
# MIO_PPS_EU27_2020                       0
# PPS_EU27_2020_HAB                       0
# PPS_HAB_EU27_2020                       0
# GVA (MIO_EUR)                           0
# GVA (MIO_NAC)                           0
# Kod                                     0
# Studenci do Ludności w wieku 19-24     74
# population men                        518
# population women                      518
# Mean_salary                            74
# Studenci                              370
# dtype: int64

# %%
# Filter the dataframe to find NaNs rows
nan_rows = forth_factor[forth_factor['Studenci'].isna()]

nan_rows['TIME_PERIOD'].unique()
# Out:
# array(['2007', '2008', '2009', '2010', '2011'], dtype=object)

# %% [markdown]
# Missing values for 2007 - 2011

# %% [markdown]
# ### Factor 5 - Ludność w miastach w % ogółu ludności (dane półroczne) 2012 - 2020

# %%
file_path = 'LUDN_2463_XTAB_20231125152108.xlsx'

# Read the specific sheet 'TABLICA'
tablica_df = pd.read_excel(file_path, sheet_name='TABLICA')

# Display the first few rows of the DataFrame 
tablica_df = tablica_df.copy()
tablica_df
# Out:
#              Kod                    Nazwa    rok Unnamed: 3 Unnamed: 4  \
# 0            NaN                      NaN   2012       2013       2014
# 1            NaN                      NaN    [%]        [%]        [%]
# 2   1.121200e+10      PODREGION KRAKOWSKI  22.86      22.78      22.72
# 3   1.121210e+10  PODREGION MIASTO KRAKÓW    100        100        100
# 4   1.121220e+10    PODREGION NOWOSĄDECKI  34.06      33.88      33.69
# ..           ...                      ...    ...        ...        ...
# 70  7.142260e+10     PODREGION OSTROŁĘCKI  36.34      36.23      36.22
# 71  7.142270e+10       PODREGION RADOMSKI  49.36       49.2      49.04
# 72  7.142700e+10         PODREGION PŁOCKI  51.21      51.02      50.92
# 73  7.142710e+10      PODREGION SIEDLECKI  36.95      37.03      37.15
# 74  7.142730e+10    PODREGION ŻYRARDOWSKI  46.04      45.92      45.81
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        2015       2016       2017       2018       2019        2020
# 1         [%]        [%]        [%]        [%]        [%]         [%]
# 2       22.67      22.65      22.61      22.57      22.61        22.2
# 3         100        100        100        100        100         100
# 4       33.56      33.42      33.27      33.07      32.93        32.4
# ..        ...        ...        ...        ...        ...         ...
# 70      36.27      36.25      36.21      36.27      36.27       36.01
# 71      48.92      48.77      48.71      48.52      48.36       47.57
# 72      50.86      50.77       50.7      51.22      51.16       50.64
# 73      37.31      37.39      37.58       37.7      37.81       37.83
# 74       45.7      45.59      45.46       45.3       45.2        44.6
#
#    Unnamed: 11 Unnamed: 12
# 0         2021        2022
# 1          [%]         [%]
# 2        22.12       22.05
# 3          100         100
# 4        32.17       31.98
# ..         ...         ...
# 70       35.89       35.77
# 71       47.51       47.95
# 72        50.5       50.29
# 73        37.9        37.9
# 74       44.95       44.74
#
# [75 rows x 13 columns]

# %%
# Get the 'rok' column data for the year 2012
rok_2012 = tablica_df[['Kod', 'Nazwa', 'rok']].copy()
rok_2012['TIME_PERIOD'] = 2012
rok_2012.rename(columns={'rok': 'population in cities in %'}, inplace=True)

# List of year columns to be melted (from 2013 to 2022)
year_columns = [f'Unnamed: {i}' for i in range(3, 13)]

# Melting the DataFrame for years 2013 to 2022
melted_tablica_df = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=year_columns, var_name='TIME_PERIOD', value_name='population in cities in %')

# Adjust TIME_PERIOD values in melted_tablica_df to correspond to years
years = [str(year) for year in range(2013, 2023)]
melted_tablica_df['TIME_PERIOD'] = melted_tablica_df['TIME_PERIOD'].map(dict(zip(year_columns, years)))

# Concatenate the data for 2012 with the rest
final_tablica_df = pd.concat([rok_2012, melted_tablica_df])

# Remove rows with NaN values in 'Kod' and 'Nazwa' columns
final_tablica_df = final_tablica_df.dropna(subset=['Kod', 'Nazwa'])
final_tablica_df.isnull().sum()
# Out:
# Kod                          0
# Nazwa                        0
# population in cities in %    0
# TIME_PERIOD                  0
# dtype: int64

# %%
# Ensure 'TIME_PERIOD' is in the correct format
final_tablica_df['TIME_PERIOD'] = final_tablica_df['TIME_PERIOD'].astype(str)
forth_factor['TIME_PERIOD'] = forth_factor['TIME_PERIOD'].astype(str)

# Ensure 'Kod' is in the correct format
final_tablica_df['Kod'] = final_tablica_df['Kod'].astype(float).astype(int).astype(str)
forth_factor['Kod'] = forth_factor['Kod'].astype(str).str.strip()

# Perform the merge
fifth_factor = pd.merge(forth_factor, final_tablica_df[['Kod', 'TIME_PERIOD', 'population in cities in %']], on=['Kod', 'TIME_PERIOD'], how='left')

# %%
fifth_factor.isnull().sum()
# Out:
# Unnamed: 0                              0
# NUTS3 CODE                              0
# TIME_PERIOD                             0
# POP (THS)                               0
# EMP (THS)                               0
# EUR_HAB                                 0
# EUR_HAB_EU27_2020                       0
# MIO_EUR                                 0
# MIO_NAC                                 0
# MIO_PPS_EU27_2020                       0
# PPS_EU27_2020_HAB                       0
# PPS_HAB_EU27_2020                       0
# GVA (MIO_EUR)                           0
# GVA (MIO_NAC)                           0
# Kod                                     0
# Studenci do Ludności w wieku 19-24     74
# population men                        518
# population women                      518
# Mean_salary                            74
# Studenci                              370
# population in cities in %             370
# dtype: int64

# %%
# Filter the dataframe to find NaNs rows
nan_rows = fifth_factor[fifth_factor['population in cities in %'].isna()]

nan_rows['TIME_PERIOD'].unique()
# Out:
# array(['2007', '2008', '2009', '2010', '2011'], dtype=object)

# %% [markdown]
# Missing values for 2007 - 2011

# %% [markdown]
# ### Factor 6 - Number of students at technological universities 2008 - 2018

# %%
tech_df = pd.read_csv('SZKO_2133_CTAB_20231123195949.csv',delimiter = ';')
tech_df.head()
# Out:
#            Kod                    Nazwa  \
# 0  11212100000  PODREGION MIASTO KRAKÓW
# 1  11212200000    PODREGION NOWOSĄDECKI
# 2  11212300000    PODREGION OŚWIĘCIMSKI
# 3  12414400000        PODREGION BIELSKI
# 4  12414500000       PODREGION BYTOMSKI
#
#    uczelnie techniczne;studenci;ogółem;2008;[osoba]  \
# 0                                             45461
# 1                                               198
# 2                                                 0
# 3                                              7955
# 4                                               181
#
#    uczelnie techniczne;studenci;ogółem;2009;[osoba]  \
# 0                                             46251
# 1                                               146
# 2                                                78
# 3                                              7613
# 4                                               200
#
#    uczelnie techniczne;studenci;ogółem;2010;[osoba]  \
# 0                                             48352
# 1                                               139
# 2                                                62
# 3                                              7390
# 4                                               659
#
#    uczelnie techniczne;studenci;ogółem;2011;[osoba]  \
# 0                                             50035
# 1                                               129
# 2                                                 0
# 3                                              7282
# 4                                               483
#
#    uczelnie techniczne;studenci;ogółem;2012;[osoba]  \
# 0                                             52052
# 1                                               136
# 2                                                 0
# 3                                              7038
# 4                                               211
#
#    uczelnie techniczne;studenci;ogółem;2013;[osoba]  \
# 0                                             50058
# 1                                                84
# 2                                                 0
# 3                                              6690
# 4                                                37
#
#    uczelnie techniczne;studenci;ogółem;2014;[osoba]  \
# 0                                             48389
# 1                                                 0
# 2                                                 0
# 3                                              6446
# 4                                                 0
#
#    uczelnie techniczne;studenci;ogółem;2015;[osoba]  \
# 0                                             45451
# 1                                                 0
# 2                                                 0
# 3                                              5826
# 4                                                 0
#
#    uczelnie techniczne;studenci;ogółem;2016;[osoba]  \
# 0                                             42942
# 1                                                 0
# 2                                                 0
# 3                                              5482
# 4                                                 0
#
#    uczelnie techniczne;studenci;ogółem;2017;[osoba]  \
# 0                                             39927
# 1                                                 0
# 2                                                 0
# 3                                              4813
# 4                                                 0
#
#    uczelnie techniczne;studenci;ogółem;2018;[osoba]  Unnamed: 13
# 0                                             36775          NaN
# 1                                                 0          NaN
# 2                                                 0          NaN
# 3                                              4442          NaN
# 4                                                 0          NaN

# %%
# Columns to be melted
year_columns = [col for col in tech_df.columns if 'uczelnie techniczne;studenci;ogółem;' in col]

# Melting the DataFrame
melted_tech_df = tech_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=year_columns, var_name='TIME_PERIOD', value_name='Tech Universities; students')

# Extracting the year from 'TIME_PERIOD' column
melted_tech_df['TIME_PERIOD'] = melted_tech_df['TIME_PERIOD'].str.extract('(\d{4})')

melted_tech_df
# Out:
#              Kod                      Nazwa TIME_PERIOD  \
# 0    11212100000    PODREGION MIASTO KRAKÓW        2008
# 1    11212200000      PODREGION NOWOSĄDECKI        2008
# 2    11212300000      PODREGION OŚWIĘCIMSKI        2008
# 3    12414400000          PODREGION BIELSKI        2008
# 4    12414500000         PODREGION BYTOMSKI        2008
# ..           ...                        ...         ...
# 479  62013900000         PODREGION SUWALSKI        2018
# 480  71412800000  PODREGION MIASTO WARSZAWA        2018
# 481  71422700000         PODREGION RADOMSKI        2018
# 482  71427000000           PODREGION PŁOCKI        2018
# 483  71427300000      PODREGION ŻYRARDOWSKI        2018
#
#      Tech Universities; students
# 0                          45461
# 1                            198
# 2                              0
# 3                           7955
# 4                            181
# ..                           ...
# 479                            0
# 480                        35544
# 481                         4056
# 482                         1586
# 483                            0
#
# [484 rows x 4 columns]

# %%
# Ensure 'TIME_PERIOD' is in the correct format
melted_tech_df['TIME_PERIOD'] = melted_tech_df['TIME_PERIOD'].astype(str)
fifth_factor['TIME_PERIOD'] = fifth_factor['TIME_PERIOD'].astype(str)

# Ensure 'Kod' is in the correct format
melted_tech_df['Kod'] = melted_tech_df['Kod'].astype(float).astype(int).astype(str)
fifth_factor['Kod'] = fifth_factor['Kod'].astype(str).str.strip()

sixth_factor = pd.merge(fifth_factor, melted_tech_df[['Kod', 'TIME_PERIOD', 'Tech Universities; students']], on=['Kod', 'TIME_PERIOD'], how='left')
sixth_factor
# Out:
#       Unnamed: 0 NUTS3 CODE TIME_PERIOD  POP (THS)  EMP (THS)  EUR_HAB  \
# 0              0      PL213        2007     756.30      428.6    13200
# 1              1      PL213        2008     756.40      428.6    15100
# 2              2      PL213        2009     761.42      428.6    12800
# 3              3      PL213        2010     757.11      428.6    14600
# 4              4      PL213        2011     758.21      433.6    15300
# ...          ...        ...         ...        ...        ...      ...
# 1031        1017      PL926        2016     259.80      108.3     9800
# 1032        1018      PL926        2017     259.70      107.8    10500
# 1033        1019      PL926        2018     259.80      107.4    11000
# 1034        1020      PL926        2019     259.10      107.1    11700
# 1035        1021      PL926        2020     258.80      107.8    12000
#
#       EUR_HAB_EU27_2020   MIO_EUR   MIO_NAC  MIO_PPS_EU27_2020  ...  \
# 0                    54   9982.27  37769.90           16084.62  ...
# 1                    60  11393.55  40015.30           16853.02  ...
# 2                    53   9755.34  42217.21           17053.12  ...
# 3                    58  11017.52  44011.69           18453.85  ...
# 4                    60  11581.62  47723.22           19738.61  ...
# ...                 ...       ...       ...                ...  ...
# 1031                 35   2556.74  11155.56            4471.49  ...
# 1032                 36   2739.42  11661.73            4595.52  ...
# 1033                 36   2857.49  12177.18            4722.54  ...
# 1034                 37   3040.11  13065.19            5001.82  ...
# 1035                 40   3093.94  13746.36            5155.48  ...
#
#       GVA (MIO_EUR)  GVA (MIO_NAC)          Kod  \
# 0           8712.37          32965  11212100000
# 1           9939.92          34910  11212100000
# 2           8659.07          37473  11212100000
# 3           9594.71          38328  11212100000
# 4          10093.43          41591  11212100000
# ...             ...            ...          ...
# 1031        2272.64           9916  71427300000
# 1032        2425.65          10326  71427300000
# 1033        2502.64          10665  71427300000
# 1034        2671.96          11483  71427300000
# 1035        2725.19          12108  71427300000
#
#       Studenci do Ludności w wieku 19-24 population men  population women  \
# 0                                    NaN            NaN               NaN
# 1                                  255.5            NaN               NaN
# 2                                  272.2            NaN               NaN
# 3                                  254.7            NaN               NaN
# 4                                  272.8            NaN               NaN
# ...                                  ...            ...               ...
# 1031                                 3.8              0                 0
# 1032                                 5.5              0                 0
# 1033                                 6.7           71.9              80.8
# 1034                                 2.1           72.2              80.6
# 1035                                 7.2           70.9              79.3
#
#      Mean_salary Studenci  population in cities in %  \
# 0            NaN      NaN                        NaN
# 1        3259.63      NaN                        NaN
# 2        3423.56      NaN                        NaN
# 3        3543.43      NaN                        NaN
# 4        3722.48      NaN                        NaN
# ...          ...      ...                        ...
# 1031     4111.52    718.0                      45.59
# 1032     4341.10    990.0                      45.46
# 1033     4582.52   1146.0                       45.3
# 1034     4902.14    344.0                       45.2
# 1035     5319.27   1129.0                       44.6
#
#       Tech Universities; students
# 0                             NaN
# 1                         45461.0
# 2                         46251.0
# 3                         48352.0
# 4                         50035.0
# ...                           ...
# 1031                          0.0
# 1032                          0.0
# 1033                          0.0
# 1034                          NaN
# 1035                          NaN
#
# [1036 rows x 22 columns]

# %%
# Read the specific sheet 'TABLICA'
tablica_df = pd.read_csv('LUDN_2730_CTAB_20231125151959.csv', delimiter = ';')

# Display the first few rows of the DataFrame 
tablica_df = tablica_df.copy()
tablica_df
# Out:
#             Kod                    Nazwa mężczyźni;ogółem;0;2012;[lata]  \
# 0   11212000000      PODREGION KRAKOWSKI                            0,0
# 1   11212100000  PODREGION MIASTO KRAKÓW                            0,0
# 2   11212200000    PODREGION NOWOSĄDECKI                            0,0
# 3   11212300000    PODREGION OŚWIĘCIMSKI                            0,0
# 4   11212400000      PODREGION TARNOWSKI                            0,0
# ..          ...                      ...                            ...
# 68  71422600000     PODREGION OSTROŁĘCKI                            0,0
# 69  71422700000       PODREGION RADOMSKI                            0,0
# 70  71427000000         PODREGION PŁOCKI                            0,0
# 71  71427100000      PODREGION SIEDLECKI                            0,0
# 72  71427300000    PODREGION ŻYRARDOWSKI                            0,0
#
#    mężczyźni;ogółem;0;2013;[lata] mężczyźni;ogółem;0;2014;[lata]  \
# 0                             0,0                           75,0
# 1                             0,0                           76,8
# 2                             0,0                           75,0
# 3                             0,0                           74,0
# 4                             0,0                           75,7
# ..                            ...                            ...
# 68                            0,0                           73,0
# 69                            0,0                           72,4
# 70                            0,0                           72,2
# 71                            0,0                            0,0
# 72                            0,0                            0,0
#
#    mężczyźni;ogółem;0;2015;[lata] mężczyźni;ogółem;0;2016;[lata]  \
# 0                            74,5                           75,0
# 1                            76,3                           77,1
# 2                            75,2                           74,7
# 3                            74,3                           74,4
# 4                            75,4                           75,6
# ..                            ...                            ...
# 68                           72,2                           73,2
# 69                           72,5                           72,5
# 70                           72,3                           72,0
# 71                            0,0                            0,0
# 72                            0,0                            0,0
#
#    mężczyźni;ogółem;0;2017;[lata] mężczyźni;ogółem;0;2018;[lata]  \
# 0                            74,6                           74,8
# 1                            76,8                           76,7
# 2                            75,2                           75,8
# 3                            74,4                           73,9
# 4                            75,7                           75,8
# ..                            ...                            ...
# 68                           72,4                           72,9
# 69                           72,6                           72,2
# 70                           72,9                           72,2
# 71                            0,0                           73,5
# 72                            0,0                           71,9
#
#    mężczyźni;ogółem;0;2019;[lata]  ... kobiety;ogółem;0;2014;[lata]  \
# 0                            74,9  ...                         82,1
# 1                            76,5  ...                         82,5
# 2                            75,5  ...                         82,4
# 3                            74,2  ...                         82,2
# 4                            75,6  ...                         82,9
# ..                            ...  ...                          ...
# 68                           73,1  ...                         81,7
# 69                           72,7  ...                         81,2
# 70                           73,0  ...                         80,4
# 71                           72,8  ...                          0,0
# 72                           72,2  ...                          0,0
#
#    kobiety;ogółem;0;2015;[lata] kobiety;ogółem;0;2016;[lata]  \
# 0                          82,0                         82,5
# 1                          82,6                         83,1
# 2                          82,4                         82,8
# 3                          81,8                         82,2
# 4                          82,8                         83,7
# ..                          ...                          ...
# 68                         82,3                         82,5
# 69                         81,4                         81,9
# 70                         81,3                         81,0
# 71                          0,0                          0,0
# 72                          0,0                          0,0
#
#    kobiety;ogółem;0;2017;[lata] kobiety;ogółem;0;2018;[lata]  \
# 0                          82,3                         82,7
# 1                          82,7                         83,2
# 2                          83,0                         83,0
# 3                          82,0                         82,1
# 4                          82,7                         83,4
# ..                          ...                          ...
# 68                         82,3                         82,3
# 69                         81,8                         81,8
# 70                         80,7                         80,7
# 71                          0,0                         82,0
# 72                          0,0                         80,8
#
#    kobiety;ogółem;0;2019;[lata] kobiety;ogółem;0;2020;[lata]  \
# 0                          82,6                         81,5
# 1                          83,0                         82,1
# 2                          82,6                         81,6
# 3                          82,0                         80,8
# 4                          82,9                         81,7
# ..                          ...                          ...
# 68                         81,5                         80,3
# 69                         81,9                         80,8
# 70                         81,0                         79,3
# 71                         82,2                         80,7
# 72                         80,6                         79,3
#
#    kobiety;ogółem;0;2021;[lata] kobiety;ogółem;0;2022;[lata] Unnamed: 24
# 0                          81,1                         82,3         NaN
# 1                          81,8                         82,3         NaN
# 2                          80,6                         82,6         NaN
# 3                          79,9                         81,2         NaN
# 4                          81,0                         82,5         NaN
# ..                          ...                          ...         ...
# 68                         80,1                         81,3         NaN
# 69                         79,8                         81,5         NaN
# 70                         78,8                         80,1         NaN
# 71                         79,6                         80,7         NaN
# 72                         78,0                         80,7         NaN
#
# [73 rows x 25 columns]

# %%
# Columns for men and women
men_columns = [col for col in tablica_df.columns if 'mężczyźni;ogółem' in col]
women_columns = [col for col in tablica_df.columns if 'kobiety;ogółem' in col]

# Melting the DataFrame for men
melted_men = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=men_columns, var_name='TIME_PERIOD', value_name='Men')
melted_men['TIME_PERIOD'] = melted_men['TIME_PERIOD'].str.extract('(\d{4})')

# Melting the DataFrame for women
melted_women = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=women_columns, var_name='TIME_PERIOD', value_name='Women')
melted_women['TIME_PERIOD'] = melted_women['TIME_PERIOD'].str.extract('(\d{4})')

# Combine the melted DataFrames
combined_df = pd.merge(melted_men, melted_women, on=['Kod', 'Nazwa', 'TIME_PERIOD'])

combined_df
# Out:
#              Kod                    Nazwa TIME_PERIOD   Men Women
# 0    11212000000      PODREGION KRAKOWSKI        2012   0,0   0,0
# 1    11212100000  PODREGION MIASTO KRAKÓW        2012   0,0   0,0
# 2    11212200000    PODREGION NOWOSĄDECKI        2012   0,0   0,0
# 3    11212300000    PODREGION OŚWIĘCIMSKI        2012   0,0   0,0
# 4    11212400000      PODREGION TARNOWSKI        2012   0,0   0,0
# ..           ...                      ...         ...   ...   ...
# 798  71422600000     PODREGION OSTROŁĘCKI        2022  72,0  81,3
# 799  71422700000       PODREGION RADOMSKI        2022  72,9  81,5
# 800  71427000000         PODREGION PŁOCKI        2022  71,8  80,1
# 801  71427100000      PODREGION SIEDLECKI        2022  72,3  80,7
# 802  71427300000    PODREGION ŻYRARDOWSKI        2022  71,4  80,7
#
# [803 rows x 5 columns]

# %%
# Cleaning the dataset
men_columns = tablica_df.columns[4:12]  # Starting from 2014
women_columns = tablica_df.columns[15:23]  # Starting from 2014
years = tablica_df.iloc[2, 4:12].values  # Getting the years starting from 2014

# Create a DataFrame for men
df_men = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=men_columns, var_name='TIME_PERIOD', value_name='mężczyźni')
df_men['TIME_PERIOD'] = df_men['TIME_PERIOD'].map(dict(zip(men_columns, years)))

# Create a DataFrame for women
df_women = tablica_df.melt(id_vars=['Kod', 'Nazwa'], value_vars=women_columns, var_name='TIME_PERIOD', value_name='kobiety')
df_women['TIME_PERIOD'] = df_women['TIME_PERIOD'].map(dict(zip(women_columns, years)))

# Merge the men and women DataFrames
final_df = pd.merge(df_men, df_women, on=['Kod', 'Nazwa', 'TIME_PERIOD'])

# Select only the relevant columns
final_df = final_df[['Kod', 'Nazwa', 'mężczyźni', 'kobiety', 'TIME_PERIOD']]

final_df
# Out:
#              Kod                    Nazwa mężczyźni kobiety TIME_PERIOD
# 0    11212000000      PODREGION KRAKOWSKI      75,0    82,1        75,0
# 1    11212100000  PODREGION MIASTO KRAKÓW      76,8    82,5        75,0
# 2    11212200000    PODREGION NOWOSĄDECKI      75,0    82,4        75,0
# 3    11212300000    PODREGION OŚWIĘCIMSKI      74,0    82,2        75,0
# 4    11212400000      PODREGION TARNOWSKI      75,7    82,9        75,0
# ..           ...                      ...       ...     ...         ...
# 871  71427100000      PODREGION SIEDLECKI      70,4    79,6        73,3
# 872  71427300000    PODREGION ŻYRARDOWSKI      70,9    79,3        73,3
# 873  71427300000    PODREGION ŻYRARDOWSKI      70,9    78,0        73,3
# 874  71427300000    PODREGION ŻYRARDOWSKI      69,7    79,3        73,3
# 875  71427300000    PODREGION ŻYRARDOWSKI      69,7    78,0        73,3
#
# [876 rows x 5 columns]

# %%
sixth_factor = sixth_factor.to_excel('all_factors_nuts3.xlsx')

# %% [markdown]
# ####  We've added six new factors at the NUTS 3 level to refine our modeling for Poland.
# A key consideration is the availability of these factors over time. Unlike our existing dataset that covers 2007-2020, these new factors are only available for the years 2014-2020. This aspect needs careful handling in our analysis and modeling process.

# %% [markdown]
# ### We will also put together factors on the NUTS 2 level for more general overview
# Again we will use mapping dataset as a baseline and use them to merge new factors with our Polish datase that doesn"t

# %% [markdown]
# ### Factor 1 Mejsca Pracy 2008 - 2022
# ***Nowo utworzone miejsca pracy to miejsca powstałe w wyniku zmian organizacyjnych, rozszerzenia lub zmiany profilu działalności oraz wszystkie miejsca pracy w jednostkach nowo powstałych.***

# %%
rynek = pd.read_csv('RYNE_3441_CTAB_20231201123702.csv', delimiter = ';')
rynek
# Out:
#         Kod                Nazwa  \
# 0         0               POLSKA
# 1    200000         DOLNOŚLĄSKIE
# 2    400000   KUJAWSKO-POMORSKIE
# 3    600000            LUBELSKIE
# 4    800000             LUBUSKIE
# 5   1000000              ŁÓDZKIE
# 6   1200000          MAŁOPOLSKIE
# 7   1400000          MAZOWIECKIE
# 8   1600000             OPOLSKIE
# 9   1800000         PODKARPACKIE
# 10  2000000            PODLASKIE
# 11  2200000            POMORSKIE
# 12  2400000              ŚLĄSKIE
# 13  2600000       ŚWIĘTOKRZYSKIE
# 14  2800000  WARMIŃSKO-MAZURSKIE
# 15  3000000        WIELKOPOLSKIE
# 16  3200000   ZACHODNIOPOMORSKIE
#
#    nowo utworzone miejsca pracy;2008;[tys. msc.]  \
# 0                                          490,6
# 1                                           43,2
# 2                                           23,6
# 3                                           13,3
# 4                                           15,2
# 5                                           31,7
# 6                                           35,4
# 7                                          110,9
# 8                                           11,5
# 9                                           16,6
# 10                                           9,3
# 11                                          20,7
# 12                                          68,9
# 13                                           7,2
# 14                                          15,1
# 15                                          51,7
# 16                                          16,3
#
#    nowo utworzone miejsca pracy;2009;[tys. msc.]  \
# 0                                          521,6
# 1                                           41,1
# 2                                           26,7
# 3                                           16,9
# 4                                           17,2
# 5                                           44,7
# 6                                           49,5
# 7                                          100,6
# 8                                           10,8
# 9                                           18,4
# 10                                          10,1
# 11                                          23,7
# 12                                          67,6
# 13                                          10,3
# 14                                          13,5
# 15                                          51,3
# 16                                          19,2
#
#    nowo utworzone miejsca pracy;2010;[tys. msc.]  \
# 0                                          609,3
# 1                                           43,7
# 2                                           25,4
# 3                                           22,6
# 4                                           13,6
# 5                                           36,4
# 6                                           57,9
# 7                                          123,2
# 8                                           14,1
# 9                                           23,7
# 10                                          17,4
# 11                                          36,6
# 12                                          70,7
# 13                                          14,7
# 14                                          17,9
# 15                                          70,5
# 16                                          20,9
#
#    nowo utworzone miejsca pracy;2011;[tys. msc.]  \
# 0                                          580,3
# 1                                           38,3
# 2                                           16,0
# 3                                           21,5
# 4                                           59,0
# 5                                           40,9
# 6                                           44,1
# 7                                          150,2
# 8                                           13,9
# 9                                           23,1
# 10                                          11,5
# 11                                          19,0
# 12                                          66,3
# 13                                          15,8
# 14                                          29,1
# 15                                          17,5
# 16                                          14,3
#
#    nowo utworzone miejsca pracy;2012;[tys. msc.]  \
# 0                                          465,0
# 1                                           33,2
# 2                                           13,2
# 3                                           17,9
# 4                                           48,8
# 5                                           28,5
# 6                                           35,8
# 7                                           93,7
# 8                                           13,4
# 9                                           20,3
# 10                                          13,0
# 11                                          18,3
# 12                                          58,7
# 13                                          14,0
# 14                                          26,4
# 15                                          18,0
# 16                                          11,9
#
#    nowo utworzone miejsca pracy;2013;[tys. msc.]  \
# 0                                          502,4
# 1                                           42,7
# 2                                           17,8
# 3                                           18,6
# 4                                           10,8
# 5                                           29,8
# 6                                           48,0
# 7                                           96,8
# 8                                            9,2
# 9                                           24,0
# 10                                           8,6
# 11                                          33,8
# 12                                          57,4
# 13                                          14,5
# 14                                          14,3
# 15                                          60,9
# 16                                          15,0
#
#    nowo utworzone miejsca pracy;2014;[tys. msc.]  \
# 0                                          614,8
# 1                                           44,6
# 2                                           25,3
# 3                                           19,7
# 4                                           11,6
# 5                                           37,7
# 6                                           48,9
# 7                                          163,0
# 8                                           12,2
# 9                                           20,2
# 10                                           7,5
# 11                                          40,4
# 12                                          61,8
# 13                                          16,1
# 14                                          14,6
# 15                                          71,8
# 16                                          19,4
#
#    nowo utworzone miejsca pracy;2015;[tys. msc.]  \
# 0                                          595,8
# 1                                           47,9
# 2                                           24,2
# 3                                           20,2
# 4                                           12,3
# 5                                           38,7
# 6                                           52,8
# 7                                          123,9
# 8                                           10,0
# 9                                           27,7
# 10                                          12,0
# 11                                          39,8
# 12                                          69,2
# 13                                          12,9
# 14                                          17,6
# 15                                          65,5
# 16                                          21,1
#
#    nowo utworzone miejsca pracy;2016;[tys. msc.]  \
# 0                                          618,7
# 1                                           51,3
# 2                                           23,4
# 3                                           25,8
# 4                                           13,1
# 5                                           37,3
# 6                                           68,6
# 7                                          122,8
# 8                                           15,2
# 9                                           22,0
# 10                                          10,9
# 11                                          40,2
# 12                                          67,3
# 13                                          13,0
# 14                                          15,7
# 15                                          66,2
# 16                                          25,9
#
#    nowo utworzone miejsca pracy;2017;[tys. msc.]  \
# 0                                          694,1
# 1                                           57,6
# 2                                           25,9
# 3                                           24,6
# 4                                           14,3
# 5                                           41,0
# 6                                           66,9
# 7                                          150,5
# 8                                           13,2
# 9                                           30,2
# 10                                          15,3
# 11                                          37,5
# 12                                          81,4
# 13                                          15,2
# 14                                          18,1
# 15                                          75,1
# 16                                          27,4
#
#    nowo utworzone miejsca pracy;2018;[tys. msc.]  \
# 0                                          717,8
# 1                                           47,6
# 2                                           31,2
# 3                                           28,2
# 4                                           11,2
# 5                                           39,5
# 6                                           68,9
# 7                                          151,7
# 8                                           14,0
# 9                                           30,5
# 10                                          11,6
# 11                                          43,5
# 12                                          96,1
# 13                                          18,5
# 14                                          16,8
# 15                                          79,4
# 16                                          29,1
#
#    nowo utworzone miejsca pracy;2019;[tys. msc.]  \
# 0                                          674,8
# 1                                           51,5
# 2                                           23,8
# 3                                           27,1
# 4                                           12,3
# 5                                           54,6
# 6                                           76,4
# 7                                          135,3
# 8                                           11,9
# 9                                           26,9
# 10                                          11,0
# 11                                          39,9
# 12                                          80,8
# 13                                          14,0
# 14                                          14,1
# 15                                          67,9
# 16                                          27,2
#
#    nowo utworzone miejsca pracy;2020;[tys. msc.]  \
# 0                                          470,4
# 1                                           45,4
# 2                                           20,3
# 3                                           17,9
# 4                                            7,7
# 5                                           29,3
# 6                                           49,5
# 7                                           98,0
# 8                                           10,4
# 9                                           21,1
# 10                                           9,8
# 11                                          28,4
# 12                                          53,6
# 13                                           8,2
# 14                                          11,3
# 15                                          43,7
# 16                                          15,9
#
#    nowo utworzone miejsca pracy;2021;[tys. msc.]  \
# 0                                          582,7
# 1                                           46,9
# 2                                           24,1
# 3                                           23,4
# 4                                           12,1
# 5                                           41,1
# 6                                           61,8
# 7                                          122,2
# 8                                           11,0
# 9                                           23,3
# 10                                          11,5
# 11                                          34,7
# 12                                          66,8
# 13                                          12,0
# 14                                          13,4
# 15                                          58,7
# 16                                          19,8
#
#    nowo utworzone miejsca pracy;2022;[tys. msc.]  Unnamed: 17
# 0                                          534,8          NaN
# 1                                           40,0          NaN
# 2                                           21,3          NaN
# 3                                           19,5          NaN
# 4                                           11,9          NaN
# 5                                           29,0          NaN
# 6                                           54,5          NaN
# 7                                          126,3          NaN
# 8                                            8,2          NaN
# 9                                           20,4          NaN
# 10                                          10,8          NaN
# 11                                          32,7          NaN
# 12                                          59,3          NaN
# 13                                          10,5          NaN
# 14                                          10,9          NaN
# 15                                          59,4          NaN
# 16                                          20,1          NaN

# %%
# Dropping the 'Unnamed: 17' column
rynek = rynek.drop(columns=['Unnamed: 17'])

# Reversing the order of the columns for the years 2018 to 2022
years_columns = rynek.columns[2:][::-1]  # Reverse the order of the year columns

# Melting the DataFrame to create 'TIME_PERIOD' and 'Miejsca Pracy' columns
melted_rynek = rynek.melt(id_vars=["Kod", "Nazwa"], 
                          value_vars=years_columns, 
                          var_name="TIME_PERIOD", 
                          value_name="Sites of Worky [tys. places]")

# Extracting the year from 'TIME_PERIOD' column
melted_rynek['TIME_PERIOD'] = melted_rynek['TIME_PERIOD'].str.extract('(\d{4})')

melted_rynek
# Out:
#          Kod                Nazwa TIME_PERIOD Sites of Worky [tys. places]
# 0          0               POLSKA        2022                        534,8
# 1     200000         DOLNOŚLĄSKIE        2022                         40,0
# 2     400000   KUJAWSKO-POMORSKIE        2022                         21,3
# 3     600000            LUBELSKIE        2022                         19,5
# 4     800000             LUBUSKIE        2022                         11,9
# ..       ...                  ...         ...                          ...
# 250  2400000              ŚLĄSKIE        2008                         68,9
# 251  2600000       ŚWIĘTOKRZYSKIE        2008                          7,2
# 252  2800000  WARMIŃSKO-MAZURSKIE        2008                         15,1
# 253  3000000        WIELKOPOLSKIE        2008                         51,7
# 254  3200000   ZACHODNIOPOMORSKIE        2008                         16,3
#
# [255 rows x 4 columns]

# %%
melted_rynek.isna().sum()
# Out:
# Kod                             0
# Nazwa                           0
# TIME_PERIOD                     0
# Sites of Worky [tys. places]    0
# dtype: int64

# %% [markdown]
# ### Factor 2 Absolwenci uniwerysetów technicznych 2008 - 2018

# %%
tech_uni = pd.read_csv('SZKO_2133_CTAB_20231201131942.csv',delimiter = ';')
tech_uni
# Out:
#         Kod               Nazwa  \
# 0         0              POLSKA
# 1    200000        DOLNOŚLĄSKIE
# 2    400000  KUJAWSKO-POMORSKIE
# 3    600000           LUBELSKIE
# 4    800000            LUBUSKIE
# 5   1000000             ŁÓDZKIE
# 6   1200000         MAŁOPOLSKIE
# 7   1400000         MAZOWIECKIE
# 8   1600000            OPOLSKIE
# 9   1800000        PODKARPACKIE
# 10  2000000           PODLASKIE
# 11  2200000           POMORSKIE
# 12  2400000             ŚLĄSKIE
# 13  2600000      ŚWIĘTOKRZYSKIE
# 14  3000000       WIELKOPOLSKIE
# 15  3200000  ZACHODNIOPOMORSKIE
#
#     uczelnie techniczne;absolwenci;ogółem;2008;[osoba]  \
# 0                                               53398
# 1                                                4939
# 2                                                 652
# 3                                                1510
# 4                                                   0
# 5                                                3484
# 6                                                6357
# 7                                                7806
# 8                                                1686
# 9                                                2722
# 10                                               2276
# 11                                               2534
# 12                                              10790
# 13                                               1225
# 14                                               3895
# 15                                               3522
#
#     uczelnie techniczne;absolwenci;ogółem;2009;[osoba]  \
# 0                                               52606
# 1                                                4876
# 2                                                 561
# 3                                                1784
# 4                                                   0
# 5                                                3780
# 6                                                6407
# 7                                                8341
# 8                                                2142
# 9                                                2463
# 10                                               2306
# 11                                               2471
# 12                                              10726
# 13                                               1238
# 14                                               3751
# 15                                               1760
#
#     uczelnie techniczne;absolwenci;ogółem;2010;[osoba]  \
# 0                                               59282
# 1                                                4885
# 2                                                 707
# 3                                                1642
# 4                                                  12
# 5                                                4393
# 6                                                6775
# 7                                                8955
# 8                                                2877
# 9                                                3019
# 10                                               3183
# 11                                               2852
# 12                                              11571
# 13                                               1188
# 14                                               4870
# 15                                               2353
#
#     uczelnie techniczne;absolwenci;ogółem;2011;[osoba]  \
# 0                                               74494
# 1                                                7084
# 2                                                 378
# 3                                                2186
# 4                                                  14
# 5                                                4815
# 6                                               11344
# 7                                                9190
# 8                                                2811
# 9                                                3886
# 10                                               3174
# 11                                               4836
# 12                                              13136
# 13                                               2017
# 14                                               4695
# 15                                               4928
#
#     uczelnie techniczne;absolwenci;ogółem;2012;[osoba]  \
# 0                                               77155
# 1                                                7015
# 2                                                 336
# 3                                                2277
# 4                                                   0
# 5                                                4929
# 6                                               12621
# 7                                                9725
# 8                                                2934
# 9                                                3638
# 10                                               3581
# 11                                               5696
# 12                                              12854
# 13                                               2013
# 14                                               4774
# 15                                               4762
#
#     uczelnie techniczne;absolwenci;ogółem;2013;[osoba]  \
# 0                                               78248
# 1                                                7435
# 2                                                 249
# 3                                                2558
# 4                                                   0
# 5                                                4208
# 6                                               12664
# 7                                               10134
# 8                                                2614
# 9                                                4331
# 10                                               3220
# 11                                               5575
# 12                                              12485
# 13                                               2469
# 14                                               5347
# 15                                               4959
#
#     uczelnie techniczne;absolwenci;ogółem;2014;[osoba]  \
# 0                                               78436
# 1                                                7492
# 2                                                 137
# 3                                                2569
# 4                                                   2
# 5                                                4317
# 6                                               12923
# 7                                               10348
# 8                                                2636
# 9                                                4610
# 10                                               2914
# 11                                               5475
# 12                                              12416
# 13                                               2402
# 14                                               5515
# 15                                               4680
#
#     uczelnie techniczne;absolwenci;ogółem;2015;[osoba]  \
# 0                                               79428
# 1                                                7732
# 2                                                 103
# 3                                                2563
# 4                                                   0
# 5                                                4505
# 6                                               13773
# 7                                                9976
# 8                                                2254
# 9                                                5206
# 10                                               2659
# 11                                               5508
# 12                                              12302
# 13                                               2666
# 14                                               5917
# 15                                               4264
#
#     uczelnie techniczne;absolwenci;ogółem;2016;[osoba]  \
# 0                                               77195
# 1                                                8198
# 2                                                  66
# 3                                                2610
# 4                                                   0
# 5                                                4309
# 6                                               13247
# 7                                                9617
# 8                                                2065
# 9                                                5209
# 10                                               2360
# 11                                               5604
# 12                                              11466
# 13                                               2473
# 14                                               5745
# 15                                               4226
#
#     uczelnie techniczne;absolwenci;ogółem;2017;[osoba]  \
# 0                                               82666
# 1                                                7988
# 2                                                  13
# 3                                                2679
# 4                                                   0
# 5                                                4011
# 6                                               14789
# 7                                               10663
# 8                                                2239
# 9                                                4841
# 10                                               3004
# 11                                               6859
# 12                                              12468
# 13                                               2716
# 14                                               6170
# 15                                               4226
#
#     uczelnie techniczne;absolwenci;ogółem;2018;[osoba]  Unnamed: 13
# 0                                               69209           NaN
# 1                                                7528           NaN
# 2                                                  42           NaN
# 3                                                2503           NaN
# 4                                                   0           NaN
# 5                                                3929           NaN
# 6                                               12335           NaN
# 7                                                9299           NaN
# 8                                                1722           NaN
# 9                                                4335           NaN
# 10                                               2494           NaN
# 11                                               4866           NaN
# 12                                               9496           NaN
# 13                                               2131           NaN
# 14                                               5224           NaN
# 15                                               3305           NaN

# %%
# Dropping the 'Unnamed: 13' column
tech_uni = tech_uni.drop(columns=['Unnamed: 13'])

# Reversing the order of the columns 
years_columns = tech_uni.columns[2:][::-1]  # Reverse the order of the year columns

# Melting the DataFrame to create 'TIME_PERIOD' and 'Miejsca Pracy' columns
melted_tech_uni = tech_uni.melt(id_vars=["Kod", "Nazwa"], 
                          value_vars=years_columns, 
                          var_name="TIME_PERIOD", 
                          value_name="Uni_tech graduates[person.]")

# Extracting the year from 'TIME_PERIOD' column
melted_tech_uni['TIME_PERIOD'] = melted_tech_uni['TIME_PERIOD'].str.extract('(\d{4})')

melted_tech_uni
# Out:
#          Kod               Nazwa TIME_PERIOD  Uni_tech graduates[person.]
# 0          0              POLSKA        2018                        69209
# 1     200000        DOLNOŚLĄSKIE        2018                         7528
# 2     400000  KUJAWSKO-POMORSKIE        2018                           42
# 3     600000           LUBELSKIE        2018                         2503
# 4     800000            LUBUSKIE        2018                            0
# ..       ...                 ...         ...                          ...
# 171  2200000           POMORSKIE        2008                         2534
# 172  2400000             ŚLĄSKIE        2008                        10790
# 173  2600000      ŚWIĘTOKRZYSKIE        2008                         1225
# 174  3000000       WIELKOPOLSKIE        2008                         3895
# 175  3200000  ZACHODNIOPOMORSKIE        2008                         3522
#
# [176 rows x 4 columns]

# %% [markdown]
# #### Factor 3 Absolwenci uniwerysetów technicznych 2008 - 2018 - Kobiety

# %%
tech_wom = pd.read_csv('SZKO_2134_CTAB_20231201135851.csv', delimiter = ';')
tech_wom
# Out:
#         Kod               Nazwa  \
# 0         0              POLSKA
# 1    200000        DOLNOŚLĄSKIE
# 2    400000  KUJAWSKO-POMORSKIE
# 3    600000           LUBELSKIE
# 4    800000            LUBUSKIE
# 5   1000000             ŁÓDZKIE
# 6   1200000         MAŁOPOLSKIE
# 7   1400000         MAZOWIECKIE
# 8   1600000            OPOLSKIE
# 9   1800000        PODKARPACKIE
# 10  2000000           PODLASKIE
# 11  2200000           POMORSKIE
# 12  2400000             ŚLĄSKIE
# 13  2600000      ŚWIĘTOKRZYSKIE
# 14  3000000       WIELKOPOLSKIE
# 15  3200000  ZACHODNIOPOMORSKIE
#
#     uczelnie techniczne;absolwenci;kobiety;2008;[osoba]  \
# 0                                               20557
# 1                                                1543
# 2                                                 164
# 3                                                 550
# 4                                                   0
# 5                                                1454
# 6                                                2175
# 7                                                3252
# 8                                                 762
# 9                                                1280
# 10                                                940
# 11                                               1002
# 12                                               4482
# 13                                                363
# 14                                               1100
# 15                                               1490
#
#     uczelnie techniczne;absolwenci;kobiety;2009;[osoba]  \
# 0                                               20269
# 1                                                1567
# 2                                                 174
# 3                                                 652
# 4                                                   0
# 5                                                1577
# 6                                                2101
# 7                                                3288
# 8                                                1011
# 9                                                1037
# 10                                                927
# 11                                                991
# 12                                               4628
# 13                                                391
# 14                                               1000
# 15                                                925
#
#     uczelnie techniczne;absolwenci;kobiety;2010;[osoba]  \
# 0                                               22571
# 1                                                1533
# 2                                                 168
# 3                                                 516
# 4                                                   0
# 5                                                1702
# 6                                                2381
# 7                                                3193
# 8                                                1299
# 9                                                1469
# 10                                               1295
# 11                                               1131
# 12                                               4969
# 13                                                340
# 14                                               1293
# 15                                               1282
#
#     uczelnie techniczne;absolwenci;kobiety;2011;[osoba]  \
# 0                                               28442
# 1                                                2220
# 2                                                 121
# 3                                                 637
# 4                                                   1
# 5                                                2054
# 6                                                3880
# 7                                                3573
# 8                                                1258
# 9                                                1676
# 10                                               1359
# 11                                               1774
# 12                                               5522
# 13                                                548
# 14                                               1250
# 15                                               2569
#
#     uczelnie techniczne;absolwenci;kobiety;2012;[osoba]  \
# 0                                               29976
# 1                                                2310
# 2                                                  92
# 3                                                 789
# 4                                                   0
# 5                                                2070
# 6                                                4383
# 7                                                3754
# 8                                                1277
# 9                                                1546
# 10                                               1603
# 11                                               2150
# 12                                               5478
# 13                                                685
# 14                                               1380
# 15                                               2459
#
#     uczelnie techniczne;absolwenci;kobiety;2013;[osoba]  \
# 0                                               32390
# 1                                                2630
# 2                                                  45
# 3                                                 953
# 4                                                   0
# 5                                                1945
# 6                                                4713
# 7                                                4296
# 8                                                1164
# 9                                                2077
# 10                                               1513
# 11                                               2385
# 12                                               5381
# 13                                                893
# 14                                               1657
# 15                                               2738
#
#     uczelnie techniczne;absolwenci;kobiety;2014;[osoba]  \
# 0                                               33063
# 1                                                2781
# 2                                                  29
# 3                                                 921
# 4                                                   0
# 5                                                2038
# 6                                                4981
# 7                                                4536
# 8                                                1179
# 9                                                2249
# 10                                               1433
# 11                                               2318
# 12                                               5269
# 13                                                981
# 14                                               1787
# 15                                               2561
#
#     uczelnie techniczne;absolwenci;kobiety;2015;[osoba]  \
# 0                                               34090
# 1                                                2925
# 2                                                  21
# 3                                                1001
# 4                                                   0
# 5                                                2151
# 6                                                5526
# 7                                                4416
# 8                                                1047
# 9                                                2343
# 10                                               1274
# 11                                               2470
# 12                                               5424
# 13                                               1149
# 14                                               2027
# 15                                               2316
#
#     uczelnie techniczne;absolwenci;kobiety;2016;[osoba]  \
# 0                                               33441
# 1                                                3193
# 2                                                   6
# 3                                                 970
# 4                                                   0
# 5                                                2060
# 6                                                5431
# 7                                                4330
# 8                                                 959
# 9                                                2411
# 10                                               1110
# 11                                               2499
# 12                                               5092
# 13                                               1061
# 14                                               2089
# 15                                               2230
#
#     uczelnie techniczne;absolwenci;kobiety;2017;[osoba]  \
# 0                                               35612
# 1                                                3174
# 2                                                   1
# 3                                                 972
# 4                                                   0
# 5                                                1954
# 6                                                6218
# 7                                                4660
# 8                                                 938
# 9                                                2302
# 10                                               1403
# 11                                               3080
# 12                                               5374
# 13                                               1118
# 14                                               2129
# 15                                               2289
#
#     uczelnie techniczne;absolwenci;kobiety;2018;[osoba]  Unnamed: 13
# 0                                               29682            NaN
# 1                                                2914            NaN
# 2                                                   6            NaN
# 3                                                 925            NaN
# 4                                                   0            NaN
# 5                                                1918            NaN
# 6                                                5123            NaN
# 7                                                4125            NaN
# 8                                                 752            NaN
# 9                                                2057            NaN
# 10                                               1127            NaN
# 11                                               2212            NaN
# 12                                               4158            NaN
# 13                                                821            NaN
# 14                                               1817            NaN
# 15                                               1727            NaN

# %%
# Dropping the 'Unnamed: 13' column
tech_wom = tech_wom.drop(columns=['Unnamed: 13'])

# Reversing the order of the columns 
years_columns = tech_wom.columns[2:][::-1]  # Reverse the order of the year columns

# Melting the DataFrame to create 'TIME_PERIOD' and 'Miejsca Pracy' columns
melted_tech_wom = tech_wom.melt(id_vars=["Kod", "Nazwa"], 
                          value_vars=years_columns, 
                          var_name="TIME_PERIOD", 
                          value_name="Women - Uni_tech graduates [person.]")

# Extracting the year from 'TIME_PERIOD' column
melted_tech_wom['TIME_PERIOD'] = melted_tech_uni['TIME_PERIOD'].str.extract('(\d{4})')

melted_tech_wom
# Out:
#          Kod               Nazwa TIME_PERIOD  \
# 0          0              POLSKA        2018
# 1     200000        DOLNOŚLĄSKIE        2018
# 2     400000  KUJAWSKO-POMORSKIE        2018
# 3     600000           LUBELSKIE        2018
# 4     800000            LUBUSKIE        2018
# ..       ...                 ...         ...
# 171  2200000           POMORSKIE        2008
# 172  2400000             ŚLĄSKIE        2008
# 173  2600000      ŚWIĘTOKRZYSKIE        2008
# 174  3000000       WIELKOPOLSKIE        2008
# 175  3200000  ZACHODNIOPOMORSKIE        2008
#
#      Women - Uni_tech graduates [person.]
# 0                                   29682
# 1                                    2914
# 2                                       6
# 3                                     925
# 4                                       0
# ..                                    ...
# 171                                  1002
# 172                                  4482
# 173                                   363
# 174                                  1100
# 175                                  1490
#
# [176 rows x 4 columns]

# %% [markdown]
# #### Factor 4 - Employment in technology and knowledge-intensive sectors by NUTS 2 regions and sex 2008 - 2020

# %%
empl_in_tech = pd.read_csv('htec_emp_reg2_page_linear.csv', delimiter = ',')
empl_in_tech
# Out:
#                      DATAFLOW        LAST UPDATE freq nace_r2     unit sex  \
# 0    ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 1    ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 2    ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 3    ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 4    ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# ..                        ...                ...  ...     ...      ...  ..
# 345  ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 346  ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 347  ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 348  ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
# 349  ESTAT:HTEC_EMP_REG2(1.0)  27/04/23 11:00:00    A     HTC  THS_PER   T
#
#       geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0     PL2         2008       67.9        b
# 1     PL2         2009       71.7      NaN
# 2     PL2         2010       67.4        b
# 3     PL2         2011       76.0      NaN
# 4     PL2         2012       86.7      NaN
# ..    ...          ...        ...      ...
# 345  PL92         2018       15.2      NaN
# 346  PL92         2019       17.0      NaN
# 347  PL92         2020       17.3        u
# 348  PL92         2021       22.0        b
# 349  PL92         2022       20.0      NaN
#
# [350 rows x 10 columns]

# %%
# Dropping some columns
empl_in_tech = empl_in_tech.drop(columns=['DATAFLOW', 'LAST UPDATE', 'freq', 'nace_r2', 'unit', 'OBS_FLAG', 'sex'])
empl_in_tech
# Out:
#       geo  TIME_PERIOD  OBS_VALUE
# 0     PL2         2008       67.9
# 1     PL2         2009       71.7
# 2     PL2         2010       67.4
# 3     PL2         2011       76.0
# 4     PL2         2012       86.7
# ..    ...          ...        ...
# 345  PL92         2018       15.2
# 346  PL92         2019       17.0
# 347  PL92         2020       17.3
# 348  PL92         2021       22.0
# 349  PL92         2022       20.0
#
# [350 rows x 3 columns]

# %%
empl_in_tech
# Out:
#       geo  TIME_PERIOD  OBS_VALUE
# 0     PL2         2008       67.9
# 1     PL2         2009       71.7
# 2     PL2         2010       67.4
# 3     PL2         2011       76.0
# 4     PL2         2012       86.7
# ..    ...          ...        ...
# 345  PL92         2018       15.2
# 346  PL92         2019       17.0
# 347  PL92         2020       17.3
# 348  PL92         2021       22.0
# 349  PL92         2022       20.0
#
# [350 rows x 3 columns]

# %%
mapping_data
# Out:
#     Unnamed: 0                                NUTS1 NUTS1 CODE  \
# 0            0                 MAKROREGION PÓŁNOCNY        PL6
# 1            1                 MAKROREGION WSCHODNI        PL8
# 2            2                 MAKROREGION PÓŁNOCNY        PL6
# 3            3               MAKROREGION POŁUDNIOWY        PL2
# 4            4                MAKROREGION CENTRALNY        PL7
# ..         ...                                  ...        ...
# 67          67        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 68          68                 MAKROREGION PÓŁNOCNY        PL6
# 69          69        MAKROREGION PÓŁNOCNO-ZACHODNI        PL4
# 70          70  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 71          71      MAKROREGION POŁUDNIOWO-ZACHODNI        PL5
#
#                           NUTS2 NUTS2 CODE                      NUTS3  \
# 0     REGION KUJAWSKO-POMORSKIE       PL61       PODREGION WROCŁAWSKI
# 1              REGION PODLASKIE       PL84         PODREGION SUWALSKI
# 2    REGION WARMIŃSKO-MAZURSKIE       PL62       PODREGION OLSZTYŃSKI
# 3                REGION ŚLĄSKIE       PL22      PODREGION SOSNOWIECKI
# 4                REGION ŁÓDZKIE       PL71      PODREGION PIOTRKOWSKI
# ..                          ...        ...                        ...
# 67         REGION WIELKOPOLSKIE       PL41    PODREGION MIASTO POZNAŃ
# 68    REGION KUJAWSKO-POMORSKIE       PL61          PODREGION ŚWIECKI
# 69    REGION ZACHODNIOPOMORSKIE       PL42  PODREGION MIASTO SZCZECIN
# 70  REGION WARSZAWSKI STOŁECZNY       PL91  PODREGION MIASTO WARSZAWA
# 71          REGION DOLNOŚLĄSKIE       PL51   PODREGION MIASTO WROCŁAW
#
#    NUTS3 CODE
# 0       PL619
# 1       PL843
# 2       PL622
# 3       PL22B
# 4       PL713
# ..        ...
# 67      PL415
# 68      PL618
# 69      PL424
# 70      PL911
# 71      PL514
#
# [72 rows x 7 columns]

# %%
column1 = empl_in_tech['geo']
column2 = mapping_data['NUTS2 CODE']

# Finding common values
common_values = set(column1).intersection(set(column2))
common_values
# Out:
# {'PL21',
#  'PL22',
#  'PL41',
#  'PL42',
#  'PL43',
#  'PL51',
#  'PL52',
#  'PL61',
#  'PL62',
#  'PL63',
#  'PL71',
#  'PL72',
#  'PL81',
#  'PL82',
#  'PL84',
#  'PL91',
#  'PL92'}

# %%
empl_in_tech.rename(columns={'geo': 'NUTS2 CODE'}, inplace=True)

# Performing the merge
merged_dataset = pd.merge(empl_in_tech, merged_df, on='NUTS2 CODE', how='inner')

# Displaying the merged dataset
merged_dataset
# Out:
#      NUTS2 CODE  TIME_PERIOD  OBS_VALUE  Unnamed: 0  \
# 0          PL21         2008       35.9        13.0
# 1          PL21         2008       35.9        17.0
# 2          PL21         2008       35.9        27.0
# 3          PL21         2008       35.9        41.0
# 4          PL21         2008       35.9        56.0
# ...         ...          ...        ...         ...
# 1055       PL92         2022       20.0        28.0
# 1056       PL92         2022       20.0        33.0
# 1057       PL92         2022       20.0        43.0
# 1058       PL92         2022       20.0        46.0
# 1059       PL92         2022       20.0        63.0
#
#                                     NUTS1 NUTS1 CODE  \
# 0                  MAKROREGION POŁUDNIOWY        PL2
# 1                  MAKROREGION POŁUDNIOWY        PL2
# 2                  MAKROREGION POŁUDNIOWY        PL2
# 3                  MAKROREGION POŁUDNIOWY        PL2
# 4                  MAKROREGION POŁUDNIOWY        PL2
# ...                                   ...        ...
# 1055  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 1056  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 1057  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 1058  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
# 1059  MAKROREGION WOJEWÓDZTWO MAZOWIECKIE        PL9
#
#                               NUTS2                    NUTS3 NUTS3 CODE  \
# 0                REGION MAŁOPOLSKIE      PODREGION KRAKOWSKI      PL214
# 1                REGION MAŁOPOLSKIE      PODREGION TARNOWSKI      PL217
# 2                REGION MAŁOPOLSKIE    PODREGION OŚWIĘCIMSKI      PL21A
# 3                REGION MAŁOPOLSKIE    PODREGION NOWOSĄDECKI      PL218
# 4                REGION MAŁOPOLSKIE  PODREGION MIASTO KRAKÓW      PL213
# ...                             ...                      ...        ...
# 1055  REGION MAZOWIECKI REGIONALNY    PODREGION CIECHANOWSKI      PL922
# 1056  REGION MAZOWIECKI REGIONALNY       PODREGION SIEDLECKI      PL925
# 1057  REGION MAZOWIECKI REGIONALNY          PODREGION PŁOCKI      PL923
# 1058  REGION MAZOWIECKI REGIONALNY     PODREGION ŻYRARDOWSKI      PL926
# 1059  REGION MAZOWIECKI REGIONALNY      PODREGION OSTROŁĘCKI      PL924
#
#               Kod
# 0     11212000000
# 1     11212400000
# 2     11212300000
# 3     11212200000
# 4     11212100000
# ...           ...
# 1055  71422500000
# 1056  71427100000
# 1057  71427000000
# 1058  71427300000
# 1059  71422600000
#
# [1060 rows x 10 columns]

# %%
merged_dataset = merged_dataset[['TIME_PERIOD', 'OBS_VALUE', 'Kod']]
merged_dataset.rename(columns={'OBS_VALUE': 'Employment in technology [THS_PER]'}, inplace=True)
merged_dataset
# Out:
# /var/folders/vn/7p3t4_3n02gcv591cgws1gw80000gn/T/ipykernel_18152/222513926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_dataset.rename(columns={'OBS_VALUE': 'Employment in technology [THS_PER]'}, inplace=True)
#       TIME_PERIOD  Employment in technology [THS_PER]          Kod
# 0            2008                                35.9  11212000000
# 1            2008                                35.9  11212400000
# 2            2008                                35.9  11212300000
# 3            2008                                35.9  11212200000
# 4            2008                                35.9  11212100000
# ...           ...                                 ...          ...
# 1055         2022                                20.0  71422500000
# 1056         2022                                20.0  71427100000
# 1057         2022                                20.0  71427000000
# 1058         2022                                20.0  71427300000
# 1059         2022                                20.0  71422600000
#
# [1060 rows x 3 columns]

# %% [markdown]
# ### Merging  Factors NUTS 2

# %%
factors_1 = melted_rynek.merge(melted_tech_uni, on =['TIME_PERIOD', 'Nazwa', 'Kod'], how ='left')
factors_1
# Out:
#          Kod                Nazwa TIME_PERIOD Sites of Worky [tys. places]  \
# 0          0               POLSKA        2022                        534,8
# 1     200000         DOLNOŚLĄSKIE        2022                         40,0
# 2     400000   KUJAWSKO-POMORSKIE        2022                         21,3
# 3     600000            LUBELSKIE        2022                         19,5
# 4     800000             LUBUSKIE        2022                         11,9
# ..       ...                  ...         ...                          ...
# 250  2400000              ŚLĄSKIE        2008                         68,9
# 251  2600000       ŚWIĘTOKRZYSKIE        2008                          7,2
# 252  2800000  WARMIŃSKO-MAZURSKIE        2008                         15,1
# 253  3000000        WIELKOPOLSKIE        2008                         51,7
# 254  3200000   ZACHODNIOPOMORSKIE        2008                         16,3
#
#      Uni_tech graduates[person.]
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 250                      10790.0
# 251                       1225.0
# 252                          NaN
# 253                       3895.0
# 254                       3522.0
#
# [255 rows x 5 columns]

# %%
factors_1.isnull().sum()
# Out:
# Kod                              0
# Nazwa                            0
# TIME_PERIOD                      0
# Sites of Worky [tys. places]     0
# Uni_tech graduates[person.]     79
# dtype: int64

# %%
factors_2 = factors_1.merge(melted_tech_wom, on =['TIME_PERIOD', 'Nazwa', 'Kod'], how ='left')
factors_2
# Out:
#          Kod                Nazwa TIME_PERIOD Sites of Worky [tys. places]  \
# 0          0               POLSKA        2022                        534,8
# 1     200000         DOLNOŚLĄSKIE        2022                         40,0
# 2     400000   KUJAWSKO-POMORSKIE        2022                         21,3
# 3     600000            LUBELSKIE        2022                         19,5
# 4     800000             LUBUSKIE        2022                         11,9
# ..       ...                  ...         ...                          ...
# 250  2400000              ŚLĄSKIE        2008                         68,9
# 251  2600000       ŚWIĘTOKRZYSKIE        2008                          7,2
# 252  2800000  WARMIŃSKO-MAZURSKIE        2008                         15,1
# 253  3000000        WIELKOPOLSKIE        2008                         51,7
# 254  3200000   ZACHODNIOPOMORSKIE        2008                         16,3
#
#      Uni_tech graduates[person.]  Women - Uni_tech graduates [person.]
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
# ..                           ...                                   ...
# 250                      10790.0                                4482.0
# 251                       1225.0                                 363.0
# 252                          NaN                                   NaN
# 253                       3895.0                                1100.0
# 254                       3522.0                                1490.0
#
# [255 rows x 6 columns]

# %%
factors = factors_2.to_excel('all_factors_nuts2.xlsx')
